# %% [markdown]
# ## Combine Fulton County Parcel and Sales Data From 2010-2021
#
# **Output:** one file which contains Fulton County sales data (as source file), with associated parcel data from the same year.
#
# **Motivation:** the sales and parcel datasets are currently separate, and each year has its own file, making it hard to analyize easily.
#
# **Data Sources:** provided by Fulton County. Originally named "STANDARDS DIGEST ATL {year}.xlxs", "{NF, SF} {year}", and "STANDARDS SALES {year}.txt", now locally named "parcel_{atl, nf, sf}_{year}" and "sales{year}".
#
# Note: ATL + NF + SF is the sum of all parcels in Fulton county.
#
# [Link to SharePoint for Data](https://gtvault-my.sharepoint.com/personal/yan74_gatech_edu/_layouts/15/onedrive.aspx?ct=1685705130558&or=OWA%2DNT&cid=208dc2f3%2D7e14%2D99f7%2D2679%2D5df5c365c078&ga=1&id=%2Fpersonal%2Fyan74%5Fgatech%5Fedu%2FDocuments%2FCounty%20Tax%20Assessment%20Data%2FFulton%20%2D%20Conley%2C%20Pinkey&view=0&noAuthRedirect=1)
#
# ---

# %% [markdown]
# ### Process
# **1. Append all Parcel data**
# - Append all Parcel_NF for years 2010-2022, Parcel_SF for years 2010-2022, and Parcel_ATL for years 2010-2022 separately. _NOTE: should only read in specified desired variables, and declare their datatype on read to improve performance and memory._
# - Check duplications in the nf_appended, sf_appended, and atl_appended.
# - Append nf_appended, sf_appended, atl_appended to each other.
# ---
# **2. Append all Sales data**
# - Append Sales for years 2010-2022. _NOTE: should only read in specified desired variables, and declare their datatype on read to improve performance and memory._
# - Check duplications in sales_appended.
# ---
# **3. Merge Sales and Parcel data.**
# - _Discussion:_ We want to merge Sales and the associated Parcel data, using Sales as the left table. This way we will have a record all of sales from 2010-2022 with that parcel's associated data. However, we must consider that some parcels have multiple buildings on them, which can be sold separately. Thus, the identifer to merge this data must consider this. Likewise, parcel data often has multiple rows when there are multiple buildings on one parcel, recording each building as a separate row but with the same ParcelID.
# - Use the key [parid, taxyr, salesprice] to merge Parcel data from the given year.
# - Check duplications in parcel_sales_merged.
# ---

# %% [markdown]
# ### Global Functions and Code

# %%
import pandas as pd
import os
pd.set_option('display.max_columns', 100)

# %% [markdown]
# Helper fuction to get specified variables from given file.

# %%
def read_file(file, folder, vars, datatypes):
    print("Reading file: ", file)
    df = pd.DataFrame()

    if file[-4:len(file)] == "xlsx":
        df = pd.read_excel(
            '../data/' + folder + '/' + file,
            index_col=False,
            usecols=vars,
            dtype=datatypes
        )
    else:
        df = pd.read_csv(
            '../data/' + folder + '/' + file + ".txt",
            sep='\t',
            dtype=datatypes
        )

    print("Successfully read file: ", file)
    return df

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Append all Parcel data to a single file.

# %% [markdown]
# Define all needed files, variables, and datatypes for reading in Parcel data.

# %%
path = "C:/Users/nicho/Documents/research/FCS/data/cmr/"
cmr_files = os.listdir(path)

path = "C:/Users/nicho/Documents/research/FCS/data/sales/"
sales_files = os.listdir(path)

# %%
# Modify variables as needed
parcel_vars = ["Taxyr", "Parid", "Nbhd", "SITUS Adrpre", "SITUS Adrno", "SITUS Adrdir", "SITUS Adrstr",
            "SITUS Adrsuf", "SITUS Adrsuf2", "SITUS Cityname", "Class", "Luc", "Livunit", "Calcacres",
            "Chgrsn", "Taxdist", "Own1", "Own2", "Careof", "OWNER Adrno", "OWNER Adrdir", "OWNER Adrstr",
            "OWNER Adrsuf", "OWNER Adrsuf2", "OWNER Cityname", "Statecode", "Country", "Unitdesc", "Unitno",
            "Zip1", "Zip2", "Reascd", "Spcflg", "Aprland", "Aprbldg", "Revcode", "Revreas", "Revland",
            "Revbldg", "Revtot", "Aprtot", "Exmppct", "Exmpval", "Cur", "Areasum", "Bldnum", "Yrblt",
            "Effyr", "Units", "Structure", "Grade", "Area", "Perim", "Stories", "Sf", "Usetype",
            "Yrblt", "Effyr", "Rentpct", "Rentsf", "Occupancy", "Msunits"]

# %%
#testcsv = pd.read_csv('../output/test.csv', dtype=parcel_vars)

# %%
parcel_datatypes = {"Taxyr": pd.StringDtype(), "Parid": pd.StringDtype()}

# %%
parcel_datatypes = {"Taxyr": pd.StringDtype(), "Parid": pd.StringDtype(),
                    "Nbhd": pd.CategoricalDtype(), "Situs Adrno": pd.Int64Dtype(),
                    "Situs Adrdir": pd.CategoricalDtype(), "Situs Adrsuf": pd.StringDtype(),
                    "Situs Adrsuf": pd.CategoricalDtype(), "Situs Adrsuf2": pd.CategoricalDtype(),
                    "Cityname": pd.CategoricalDtype(), "Zoning": pd.CategoricalDtype(), "Muni": pd.CategoricalDtype(),
                    "Class": pd.CategoricalDtype(), "Luc": pd.CategoricalDtype(), "Livunit": pd.CategoricalDtype(),
                    "Calcacres": pd.CategoricalDtype(), "Location": pd.CategoricalDtype(),
                    "Fronting": pd.CategoricalDtype(), "Street1": pd.CategoricalDtype(),
                    "Util1": pd.CategoricalDtype(), "Util2": pd.CategoricalDtype(), "Util3": pd.CategoricalDtype(),
                    "Parkprox": pd.CategoricalDtype(), "Parkquanit": pd.CategoricalDtype(),
                    "Parktype": pd.CategoricalDtype(), "Note1": pd.StringDtype(),
                    "Note2": pd.StringDtype(), "Note3": pd.StringDtype(),
                    "Note4": pd.StringDtype(), "Notecd1": pd.CategoricalDtype(),
                    "Notecd2": pd.CategoricalDtype(), "Bldgros D": pd.CategoricalDtype(),
                    "Bldgros V": pd.CategoricalDtype(), "Mscbld N": pd.CategoricalDtype(),
                    "Mscbld V": pd.CategoricalDtype(), "Chgrsn": pd.CategoricalDtype(), "Taxdist": pd.CategoricalDtype(),
                    "Own1": pd.StringDtype(), "Own2": pd.StringDtype(),
                    "Owner Adrno": pd.Int64Dtype(), "Owner Adradd": pd.CategoricalDtype(),
                    "Owner Adrdir": pd.CategoricalDtype(), "Owner Adrstr": pd.StringDtype(),
                    "Owner Adrsuf": pd.CategoricalDtype(), "Owner Adrsuf2": pd.CategoricalDtype(),
                    "Cityname": pd.StringDtype(), "Statecode": pd.CategoricalDtype(),
                    "Country": pd.CategoricalDtype(), "Unitno": pd.Int64Dtype(),
                    "Zip1": pd.CategoricalDtype(), "Reascd": pd.CategoricalDtype(), "Spcflg": pd.CategoricalDtype(),
                    "Aprland": pd.Float64Dtype(), "Aprbldg": pd.Float64Dtype(),
                    "Revcode": pd.CategoricalDtype(), "Revreas": pd.CategoricalDtype(), "Revland": pd.Float64Dtype(),
		            "Revbldg": pd.Float64Dtype(), "Aprtot": pd.Float64Dtype(),
		            "Aprtot": pd.Float64Dtype(), "D Card": pd.CategoricalDtype(), "Stories": pd.CategoricalDtype(),
		            "Extwall": pd.CategoricalDtype(), "Style": pd.CategoricalDtype(), "D Yrblt": pd.CategoricalDtype(),
		            "D Effyr": pd.CategoricalDtype(), "D Yrremod": pd.CategoricalDtype(), "Rmtot": pd.CategoricalDtype(),
		            "Rmbed": pd.CategoricalDtype(), "Rmfam": pd.CategoricalDtype(), "Fixbath": pd.CategoricalDtype(),
		            "Fixhalf": pd.CategoricalDtype(), "Fixaddl": pd.CategoricalDtype(), "Fixtot": pd.CategoricalDtype(),
		            "Plumval": pd.Float64Dtype(), "Bsmt": pd.CategoricalDtype(), "Bsmtval": pd.Float64Dtype(),
                    "Heat": pd.CategoricalDtype(), "Fuel": 'category', "Heatsys": pd.CategoricalDtype(), "Heatval": pd.Int32Dtype(),
                    "Attic": pd.CategoricalDtype(), "Atticval": pd.CategoricalDtype(), "Recromarea": pd.Int32Dtype(),
		            "Recval": pd.Float64Dtype(), "Ufeatarea": pd.Int32Dtype(), "Ufeatval": pd.Float64Dtype(),
                    "Wbfp O": pd.CategoricalDtype(), "Wbfp S": pd.CategoricalDtype(), "Wbfp Pf": pd.CategoricalDtype(),
                    "Wbfpval": pd.Float64Dtype(), "Condolvl": pd.CategoricalDtype(), "Condovw": pd.CategoricalDtype(),
		            "Mgfa": pd.Int32Dtype(), "Sfla": pd.Int32Dtype(), "Areafact": pd.Float64Dtype(),
                    "Shfact": pd.CategoricalDtype(), "D Grade": pd.CategoricalDtype(), "D Grdfact": pd.CategoricalDtype(),
                    "Cddesc": pd.CategoricalDtype(), "Cdpct": pd.CategoricalDtype(), "D Cdu": pd.CategoricalDtype(),
                    "Adjfact 2": pd.Float64Dtype(), "D Pctcomplete": pd.CategoricalDtype(), "Cur": pd.CategoricalDtype()}

# %%
#test_xl.astype(parcel_datatypes, errors='ignore').dtypes

# %%
#test_xl.info(verbose=True)

# %% [markdown]
# Read in all Parcel files.

# %%
#Took ~15 min to read in all files on previous run.

parcel_dfs = dict()

for file in cmr_files:
    parcel_dfs[file] = read_file(file, 'cmr', parcel_vars, parcel_datatypes)

print("Finished reading in all CMR Parcel files")
# Out:
# Reading file:  cmr2011.xlsx
# Successfully read file:  cmr2011.xlsx
# Reading file:  cmr2012.xlsx
# Successfully read file:  cmr2012.xlsx
# Reading file:  cmr2013.xlsx
# Successfully read file:  cmr2013.xlsx
# Reading file:  cmr2014.xlsx
# Successfully read file:  cmr2014.xlsx
# Reading file:  cmr2015.xlsx
# Successfully read file:  cmr2015.xlsx
# Reading file:  cmr2016.xlsx
# Successfully read file:  cmr2016.xlsx
# Reading file:  cmr2017.xlsx
# Successfully read file:  cmr2017.xlsx
# Reading file:  cmr2018.xlsx
# Successfully read file:  cmr2018.xlsx
# Reading file:  cmr2019.xlsx
# Successfully read file:  cmr2019.xlsx
# Reading file:  cmr2020.xlsx
# Successfully read file:  cmr2020.xlsx
# Reading file:  cmr2021.xlsx
# Successfully read file:  cmr2021.xlsx
# Reading file:  cmr2022.xlsx
# Successfully read file:  cmr2022.xlsx
# Finished reading in all CMR Parcel files

# %% [markdown]
# Append each file to the end of the previous, starting with "cmr2011"
# AND
# Calcuate the percent of entire row duplications (excludes the first observation) and drop these (all duplicates except the first).

# %%
parcel_total = pd.concat(list(parcel_dfs.values()))

prev_len = len(parcel_total.index)
parcel_total.drop_duplicates(inplace=True)

print("Number of entire rows duplicated (auto dropped): ", prev_len - len(parcel_total.index))
print("Percent: ", (prev_len - len(parcel_total.index)) / prev_len * 100)
print("Final size (after dropping entire row duplications): ", parcel_total.shape)
# Out:
# Number of entire rows duplicated (auto dropped):  85585
# Percent:  10.698793674604664
# Final size (after dropping entire row duplications):  (714365, 60)

# %% [markdown]
# Calculate the percent of data with duplicate Parid and duplicate [Parid, Taxyr];
# AND
# Calculate the number of unique [Parid, Taxyr] keys and the number of unique Parid keys (e.g. the number of parcels).
#
# **VERIFY: is 32,359 parcels the correct number for Fulton county?**

# %%
parid_dup = parcel_total.duplicated(subset='Parid').sum()
print("Number of rows with the a duplicate Parid: ", parid_dup)
print("Percent: ", parid_dup / len(parcel_total.index) * 100)

print("-------")

parid_taxyr_dup = parcel_total.duplicated(subset=['Parid', 'Taxyr']).sum()
print("Number of rows with the a duplicate ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(parcel_total.index) * 100)

print("-------")

concat_parid_taxyr = parcel_total.drop_duplicates(subset=['Parid', 'Taxyr'])
print("Number of unique values of [Parid, Taxyr] combination: ", len(concat_parid_taxyr.index))

print("-------")

concat_parid_taxyr = parcel_total.drop_duplicates(subset=['Parid'])
print("Number of unique values of Parid (e.g. number of parcels): ", len(concat_parid_taxyr.index))
# Out:
# Number of rows with the a duplicate Parid:  682006
# Percent:  95.47024280304886
# -------
# Number of rows with the a duplicate ['Parid', 'Taxyr']:  372901
# Percent:  52.20034576162046
# -------
# Number of unique values of [Parid, Taxyr] combination:  341464
# -------
# Number of unique values of Parid (e.g. number of parcels):  32359

# %% [markdown]
# We want to use ['Parid', 'Taxyr'] as a key, however, there is a chance that a property might have been sold twice during one year.
#
# We see that a high percent of ['Parid', 'Taxyr'] keys are duplicated. This is not due to properties being sold multiple times in one year. Rather, this is due to some

# %%
#parcel_sample = parcel_total.groupby(['Parid', 'Taxyr']).astype(float).diff()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 parcel_sample = parcel_total.groupby(['Parid', 'Taxyr']).astype(float).diff()
#
# File c:\Users\nicho\anaconda3\envs\fcs\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'astype'

# %%
parcel_col_change_test = parcel_total.drop(["Area","Luc", "Unitno", "Perim","Sf","Rentsf","Bldnum","Units","Yrblt","Effyr","Structure","Grade","Stories","Usetype","Rentpct", "Revreas", "Revbldg"], axis=1)

# %%
parcel_col_change_test.columns
# Out:
# Index(['Taxyr', 'Parid', 'Nbhd', 'SITUS Adrpre', 'SITUS Adrno', 'SITUS Adrdir',
#        'SITUS Adrstr', 'SITUS Adrsuf', 'SITUS Adrsuf2', 'SITUS Cityname',
#        'Class', 'Livunit', 'Calcacres', 'Chgrsn', 'Taxdist', 'Own1', 'Own2',
#        'Careof', 'OWNER Adrno', 'OWNER Adrdir', 'OWNER Adrstr', 'OWNER Adrsuf',
#        'OWNER Adrsuf2', 'OWNER Cityname', 'Statecode', 'Country', 'Unitdesc',
#        'Zip1', 'Zip2', 'Reascd', 'Spcflg', 'Aprland', 'Aprbldg', 'Revcode',
#        'Revland', 'Revtot', 'Aprtot', 'Exmppct', 'Exmpval', 'Cur', 'Areasum',
#        'Occupancy', 'Msunits'],
#       dtype='object')

# %%
dup_after_drop = parcel_col_change_test.duplicated(subset=['Parid', 'Taxyr']).sum()
print("Number of rows with the a duplicate ['Parid', 'Taxyr']: ", dup_after_drop)
print("Percent: ", dup_after_drop / len(parcel_col_change_test.index) * 100)
# Out:
# Number of rows with the a duplicate ['Parid', 'Taxyr']:  372901
# Percent:  52.20034576162046

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Append all Sales Data to a single file.

# %%
sales_files = ["Sales2011", "Sales2012", "Sales2013", "Sales2014",
             "Sales2015", "Sales2016", "Sales2017", "Sales2018",
             "Sales2019", "Sales2020", "Sales2021", "Sales2022"]

sales_vars = None # Since we are taking all variables in the file, we don't need to specify.

sales_datatypes = {"Taxyr": pd.StringDtype(), "Parid": pd.StringDtype()}

# %%
#Took 6 sec to read in all files on previous run.

sales_dfs = dict()

for file in sales_files:
    sales_dfs[file] = read_file(file, "sales", sales_vars, sales_datatypes)

print("Finished reading in all Sales files")
# Out:
# Reading file:  Sales2011
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (10,26,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2011
# Reading file:  Sales2012
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2012
# Reading file:  Sales2013
# Successfully read file:  Sales2013
# Reading file:  Sales2014
# Successfully read file:  Sales2014
# Reading file:  Sales2015
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2015
# Reading file:  Sales2016
# Successfully read file:  Sales2016
# Reading file:  Sales2017
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (6,26,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2017
# Reading file:  Sales2018
# Successfully read file:  Sales2018
# Reading file:  Sales2019
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (6,26,38,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2019
# Reading file:  Sales2020
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (11,26,38,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2020
# Reading file:  Sales2021
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Successfully read file:  Sales2021
# Reading file:  Sales2022
# Successfully read file:  Sales2022
# Finished reading in all Sales files
# C:\Users\nicho\AppData\Local\Temp\ipykernel_10872\3323725734.py:13: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
sales2015 = pl.

# %%
appended_cmr = pd.concat(parcel_dfs.values())

appended_cmr.to_csv("../output/appended_cmr.csv")

# %%
appended_sales = pd.concat(sales_dfs.values())

appended_cmr.to_csv("../output/appended_sales.csv")

# %%
appended_cmr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 799950 entries, 0 to 68811
# Data columns (total 60 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Taxyr           799938 non-null  string
#  1   Parid           799950 non-null  string
#  2   Nbhd            799938 non-null  object
#  3   SITUS Adrpre    0 non-null       float64
#  4   SITUS Adrno     799290 non-null  float64
#  5   SITUS Adrdir    2351 non-null    object
#  6   SITUS Adrstr    799922 non-null  object
#  7   SITUS Adrsuf    781960 non-null  object
#  8   SITUS Adrsuf2   415953 non-null  object
#  9   SITUS Cityname  790024 non-null  object
#  10  Class           799938 non-null  object
#  11  Luc             799780 non-null  object
#  12  Livunit         698945 non-null  float64
#  13  Calcacres       756945 non-null  float64
#  14  Chgrsn          735414 non-null  object
#  15  Taxdist         799938 non-null  object
#  16  Own1            799938 non-null  object
#  17  Own2            81723 non-null   object
#  18  Careof          186391 non-null  object
#  19  OWNER Adrno     681199 non-null  float64
#  20  OWNER Adrdir    57926 non-null   object
#  21  OWNER Adrstr    783055 non-null  object
#  22  OWNER Adrsuf    651986 non-null  object
#  23  OWNER Adrsuf2   223037 non-null  object
#  24  OWNER Cityname  783664 non-null  object
#  25  Statecode       783314 non-null  object
#  26  Country         228 non-null     object
#  27  Unitdesc        287786 non-null  object
#  28  Unitno          306826 non-null  object
#  29  Zip1            781825 non-null  object
#  30  Zip2            160441 non-null  object
#  31  Reascd          440723 non-null  object
#  32  Spcflg          697 non-null     object
#  33  Aprland         797674 non-null  float64
#  34  Aprbldg         796978 non-null  float64
#  35  Revcode         680240 non-null  float64
#  36  Revreas         499631 non-null  object
#  37  Revland         585366 non-null  float64
#  38  Revbldg         580785 non-null  float64
#  39  Revtot          588681 non-null  float64
#  40  Aprtot          799938 non-null  float64
#  41  Exmppct         22250 non-null   float64
#  42  Exmpval         794824 non-null  float64
#  43  Cur             799938 non-null  object
#  44  Areasum         794824 non-null  float64
#  45  Bldnum          662303 non-null  object
#  46  Yrblt           662830 non-null  float64
#  47  Effyr           177415 non-null  float64
#  48  Units           582765 non-null  float64
#  49  Structure       662830 non-null  float64
#  50  Grade           662621 non-null  object
#  51  Area            661927 non-null  float64
#  52  Perim           661927 non-null  float64
#  53  Stories         661928 non-null  float64
#  54  Sf              661928 non-null  float64
#  55  Usetype         661928 non-null  float64
#  56  Rentpct         627204 non-null  float64
#  57  Rentsf          661928 non-null  float64
#  58  Occupancy       0 non-null       float64
#  59  Msunits         0 non-null       float64
# dtypes: float64(28), object(30), string(2)
# memory usage: 372.3+ MB

# %%
appended_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477238 entries, 0 to 58757
# Data columns (total 49 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Taxyr                477226 non-null  string
#  1   Saledt: Year (YYYY)  477226 non-null  float64
#  2   Saledt: Month (Mon)  477226 non-null  object
#  3   Taxdist              477226 non-null  object
#  4   Parid                477238 non-null  string
#  5   Nbhd                 477226 non-null  object
#  6   Class                477225 non-null  object
#  7   Luc                  477226 non-null  object
#  8   Saledt               477226 non-null  object
#  9   Book                 477198 non-null  object
#  10  Page                 477183 non-null  object
#  11  SALES PRICE          477170 non-null  object
#  12  FAIR MARKET VALUE    477226 non-null  object
#  13  DEED TYPE            477220 non-null  object
#  14  Aprland              477205 non-null  object
#  15  Aprbldg              475693 non-null  object
#  16  Costval              477226 non-null  object
#  17  Saleval              477057 non-null  object
#  18  Who                  477226 non-null  object
#  19  Wen                  477226 non-null  object
#  20  GRANTOR              477201 non-null  object
#  21  GRANTEE              477218 non-null  object
#  22  Revcode              279644 non-null  float64
#  23  Reascd               338814 non-null  object
#  24  Adrpre               0 non-null       float64
#  25  Adrno                477177 non-null  float64
#  26  Adrdir               451 non-null     object
#  27  Adrstr               477195 non-null  object
#  28  Adrsuf               448604 non-null  object
#  29  Adrsuf2              191290 non-null  object
#  30  Cityname             475072 non-null  object
#  31  Unitno               78582 non-null   object
#  32  Livunit              469997 non-null  float64
#  33  Calcacres            469967 non-null  float64
#  34  Zoning               477226 non-null  object
#  35  Notecd1              37528 non-null   object
#  36  Notecd2              3579 non-null    float64
#  37  Chgrsn               441990 non-null  object
#  38  Cur                  477226 non-null  object
#  39  Cur.1                477226 non-null  object
#  40  Whocalc              223144 non-null  object
#  41  Wencalc              199551 non-null  object
#  42  Saletype             303410 non-null  object
#  43  Appraiser ID         341340 non-null  object
#  44  Income               341892 non-null  object
#  45  Bldgros V            3722 non-null    float64
#  46  Mscbld V             10472 non-null   float64
#  47  Val30 SUM            304476 non-null  float64
#  48  Areasum              304521 non-null  float64
# dtypes: float64(11), object(36), string(2)
# memory usage: 182.1+ MB

# %%
merged = appended_sales.merge(appended_cmr, how="left", on=['Taxyr', 'Parid', 'Livunit'])

# %%
merged[merged['Areasum_x'] == None]
# Out:
# Empty DataFrame
# Columns: [Taxyr, Saledt: Year (YYYY), Saledt: Month (Mon), Taxdist_x, Parid, Nbhd_x, Class_x, Luc_x, Saledt, Book, Page, SALES PRICE, FAIR MARKET VALUE, DEED TYPE, Aprland_x, Aprbldg_x, Costval, Saleval, Who, Wen, GRANTOR, GRANTEE, Revcode_x, Reascd_x, Adrpre, Adrno, Adrdir, Adrstr, Adrsuf, Adrsuf2, Cityname, Unitno_x, Livunit, Calcacres_x, Zoning, Notecd1, Notecd2, Chgrsn_x, Cur_x, Cur.1, Whocalc, Wencalc, Saletype, Appraiser ID, Income, Bldgros V, Mscbld V, Val30 SUM, Areasum_x, Nbhd_y, SITUS Adrpre, SITUS Adrno, SITUS Adrdir, SITUS Adrstr, SITUS Adrsuf, SITUS Adrsuf2, SITUS Cityname, Class_y, Luc_y, Calcacres_y, Chgrsn_y, Taxdist_y, Own1, Own2, Careof, OWNER Adrno, OWNER Adrdir, OWNER Adrstr, OWNER Adrsuf, OWNER Adrsuf2, OWNER Cityname, Statecode, Country, Unitdesc, Unitno_y, Zip1, Zip2, Reascd_y, Spcflg, Aprland_y, Aprbldg_y, Revcode_y, Revreas, Revland, Revbldg, Revtot, Aprtot, Exmppct, Exmpval, Cur_y, Areasum_y, Bldnum, Yrblt, Effyr, Units, Structure, Grade, Area, Perim, Stories, ...]
# Index: []
#
# [0 rows x 106 columns]

# %%
merged.to_csv("sales_parcel_merged.csv")

# %%
sales_appended = pd.concat(list(sales_dfs.values()))

prev_len = len(sales_appended.index)
sales_appended.drop_duplicates(inplace=True)

print("Number of entire rows duplicated (auto dropped): ", prev_len - len(sales_appended.index))
print("Percent: ", (prev_len - len(sales_appended.index)) / prev_len * 100)
print("Final size (after dropping entire row duplications): ", sales_appended.shape)
# Out:
# Number of entire rows duplicated (auto dropped):  63
# Percent:  0.013200960527032634
# Final size (after dropping entire row duplications):  (477175, 49)

# %%
parid_dup = sales_appended.duplicated(subset='Parid').sum()
print("Number of rows with the same Parid: ", parid_dup)
print("Percent: ", parid_dup / len(sales_appended.index) * 100)
print("-------")

parid_taxyr_dup = sales_appended.duplicated(subset=['Parid', 'Taxyr']).sum()
print("Number of rows with the same ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(sales_appended.index) * 100)
# Out:
# Number of rows with the same Parid:  253529
# Percent:  53.13124115890396
# -------
# Number of rows with the same ['Parid', 'Taxyr']:  96444
# Percent:  20.211452821291978

# %%
sales_appended.head(4)
# Out:
#   Taxyr  Saledt: Year (YYYY) Saledt: Month (Mon) Taxdist            Parid  \
# 0  2011               2010.0                 Oct      59  06 0310  LL0417
# 1  2011               2010.0                 Jun      59  06 0310  LL0490
# 2  2011               2010.0                 Jul      59  06 0310  LL0581
# 3  2011               2010.0                 Sep      59  06 0310  LL0755
#
#    Nbhd Class  Luc       Saledt     Book   Page SALES PRICE FAIR MARKET VALUE  \
# 0  0604    R4  100  20-OCT-2010  49589.0  00558           0            36,700
# 1  2116    R3  101  07-JUN-2010  49098.0   0288     794,600           717,100
# 2  2116    R3  101  14-JUL-2010  49244.0  00522     800,000           590,400
# 3  0604    R3  100  21-SEP-2010  49422.0   0626     200,000            97,500
#
#   DEED TYPE   Aprland   Aprbldg   Costval Saleval        Who          Wen  \
# 0        WD   36700.0       0.0   36700.0       T  TA_TJONES  09-DEC-2010
# 1        WD  195000.0  522100.0  717100.0       0    FIXSALV  04-MAR-2011
# 2        WD  127700.0  462700.0  590400.0       0    FIXSALV  04-MAR-2011
# 3        LW   97500.0       0.0  104200.0       M  TA_LPRICE  26-OCT-2010
#
#                     GRANTOR                                GRANTEE  Revcode  \
# 0         MORRISON MARION A                            WOODALL LLC      1.0
# 1             CDG HOMES LLC           EDMUNDS KEITH S & KIMBERLY C      1.0
# 2  CAPITAL DESIGN HOMES LLC  MEHDIPOUR MOHAMMADREZ & SADEGHI SHIVA      NaN
# 3              REGIONS BANK                     IHD INVESTMENT INC      3.0
#
#   Reascd  Adrpre   Adrno Adrdir             Adrstr Adrsuf Adrsuf2  \
# 0    NaN     NaN     0.0    NaN  OLD LAWRENCEVILLE     RD     NaN
# 1     00     NaN  3916.0    NaN           DAHLWINY     CT     NaN
# 2     00     NaN  3952.0    NaN           DAHLWINY     CT     NaN
# 3     SB     NaN  7615.0    NaN            REGENCY    CIR     NaN
#
#         Cityname Unitno  Livunit  Calcacres Zoning Notecd1  Notecd2 Chgrsn  \
# 0            FUL    NaN      0.0      6.200    AG1     NaN      NaN     MN
# 1  SANDY SPRINGS    NaN      1.0      0.350    CUP     NaN      NaN     NC
# 2            FUL    NaN      1.0      0.350    AG1     NaN      NaN     MN
# 3            FUL    NaN      0.0      0.522    R3C    11.0      NaN     MN
#
#   Cur Cur.1 Whocalc Wencalc Saletype Appraiser ID Income  Bldgros V  Mscbld V  \
# 0   Y     Y     NaN     NaN      NaN          NaN    NaN        NaN       NaN
# 1   Y     Y     NaN     NaN      NaN          NaN    NaN        NaN       NaN
# 2   Y     Y     NaN     NaN      NaN          NaN    NaN        NaN       NaN
# 3   Y     Y     NaN     NaN      NaN          NaN    NaN        NaN       NaN
#
#    Val30 SUM  Areasum
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN

# %%
parid_taxyr_dup = sales_appended.duplicated(subset=['Parid', 'Taxyr','SALES PRICE']).sum()
print("Number of rows with the same ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(sales_appended.index) * 100)
# Out:
# Number of rows with the same ['Parid', 'Taxyr']:  30274
# Percent:  6.344422905642584

# %%
parid_taxyr_dup = sales_appended.duplicated(subset=['Parid', 'Taxyr','Saledt']).sum()
print("Number of rows with the same ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(sales_appended.index) * 100)
# Out:
# Number of rows with the same ['Parid', 'Taxyr']:  47236
# Percent:  9.89909362393252

# %%
nbhrs = pd.read_csv('../data/parcel/select_parcels.csv')

# %%
nbhrs.head(4)
# Out:
#       FID  OBJECTID         ParcelID          Address  \
# 0  292925    344032  07 351100620022     115 ANNA AVE
# 1  292934    344041  07 351100620253     205 ANNA AVE
# 2   12845     14741  07 351100620410     210 ANNA AVE
# 3   20645     23097  09F170900670015  235 MARGARET ST
#
#                                    Match_addr          X          Y  \
# 0      115 Anne St SE, Atlanta, GA 30315, USA -84.382553  33.712952
# 1      205 Anne St SE, Atlanta, GA 30315, USA -84.381531  33.712879
# 2      210 Anne St SE, Atlanta, GA 30315, USA -84.382027  33.713051
# 3  235 Margaret St SE, Atlanta, GA 30315, USA -84.381340  33.711422
#
#                           MatchType_          FIPS  DistoCityc  TaxYear  \
# 0  RANGE_INTERPOLATED street_address  131210000000   4658.9771     2023
# 1  RANGE_INTERPOLATED street_address  131210000000   4676.0293     2023
# 2  RANGE_INTERPOLATED street_address  131210000000   4652.1650     2023
# 3  RANGE_INTERPOLATED street_address  131210000000   4838.6426     2023
#
#    AddrNumber  AddrPreDir AddrStreet AddrSuffix AddrPosDir AddrUntTyp  \
# 0         115         NaN       ANNA        AVE        NaN        NaN
# 1         205         NaN       ANNA        AVE        NaN        NaN
# 2         210         NaN       ANNA        AVE        NaN        NaN
# 3         235         NaN   MARGARET         ST        NaN        NaN
#
#   AddrUnit                    Owner                       OwnerAddr1  \
# 0      NaN     TRANS AM SFE II LLC        5001 PLAZA ON THE LK # 200
# 1      NaN    CHEEKS AVERY STANLEY                      205 ANNA AVE
# 2      NaN  KENNEDY WILLIAM EDWARD                      210 ANNA AVE
# 3      NaN          NGUYEN CHINH H   2451 CUMBERLAND PKWY SE # #3487
#
#           OwnerAddr2 TaxDist  TotAssess  LandAssess  ImprAssess  TotAppr  \
# 0    AUSTIN TX 78746      40      46960        8520       38440   117400
# 1  PALMETTO GA 30268      40      50080        8520       41560   125200
# 2  PALMETTO GA 30268      40      51200        8520       42680   128000
# 3   ATLANTA GA 30339      25       5560        5560           0    13900
#
#    LandAppr  ImprAppr LUCode ClassCode  ExCode  LivUnits  LandAcres NbrHood  \
# 0     21300     96100    101        R3     NaN       1.0     0.5022    7022
# 1     21300    103900    101        R3     NaN       1.0     0.5000    7022
# 2     21300    106700    101        R3     NaN       1.0     0.5000    7022
# 3     13900         0    100        R3     NaN       1.0     0.3450   96215
#
#    Subdiv SubdivNum SubdivLot SubdivBlck        FeatureID  Shape__Area  \
# 0     NaN       NaN       NaN        NaN  07 351100620022   21918.3260
# 1     NaN       NaN       NaN        NaN  07 351100620253   21899.5370
# 2     NaN       NaN       NaN        NaN  07 351100620410   21838.9820
# 3     NaN       NaN       NaN        NaN  09F170900670015    5900.1147
#
#    Shape__Length   neighborhood
# 0      600.68976  South Atlanta
# 1      600.40112  South Atlanta
# 2      595.98987  South Atlanta
# 3      645.52936  South Atlanta

# %%
merged = sales_appended.merge(nbhrs, how='inner', left_on=['Parid'], right_on=['ParcelID'])

# %%
merged.head(3)
# Out:
#   Taxyr  Saledt: Year (YYYY) Saledt: Month (Mon) Taxdist            Parid  \
# 0  2011               2010.0                 Sep      65  07 230000570315
# 1  2011               2010.0                 Sep      65  07 230000570315
# 2  2013               2012.0                 Feb      65  07 230000570315
#
#    Nbhd Class  Luc       Saledt     Book   Page SALES PRICE FAIR MARKET VALUE  \
# 0  0700    R3  101  07-SEP-2010  49440.0   0112      69,555            59,700
# 1  0700    R3  101  07-SEP-2010  50106.0   0520      69,555            59,700
# 2  0700    R3  101  24-FEB-2012  50936.0  575.0      35,000            52,000
#
#   DEED TYPE  Aprland  Aprbldg  Costval Saleval         Who          Wen  \
# 0        DP  16700.0  43000.0  59700.0       5   TA_TJONES  28-OCT-2010
# 1        SW  16700.0  43000.0  59700.0       9   TA_LPRICE  16-JUN-2011
# 2        SW  12600.0  39400.0  52000.0       2  TA_RAUGUST  06-NOV-2012
#
#                                     GRANTOR                       GRANTEE  \
# 0                            CRUSE WANDA M.     EVERHOME MORTGAGE COMPANY
# 1                  EVERHOME MORTGAG COMPANY  SECRETARY OF HOUSING & URBAN
# 2  SECRETARY OF HOUSING AND URBAN DEVELOPME                 ALLEN DIANE M
#
#    Revcode Reascd  Adrpre   Adrno Adrdir    Adrstr Adrsuf Adrsuf2 Cityname  \
# 0      NaN    NaN     NaN  7495.0    NaN  PHILLIPS     RD     NaN      FUL
# 1      NaN    NaN     NaN  7495.0    NaN  PHILLIPS     RD     NaN      FUL
# 2      NaN    NaN     NaN  7495.0    NaN  PHILLIPS     RD     NaN      FUL
#
#   Unitno  Livunit  Calcacres Zoning Notecd1  Notecd2 Chgrsn Cur Cur.1 Whocalc  \
# 0    NaN      1.0        1.0    AG1     NaN      NaN     RV   Y     Y     NaN
# 1    NaN      1.0        1.0    AG1     NaN      NaN     RV   Y     Y     NaN
# 2    NaN      1.0        1.0    AG1     NaN      NaN     MN   Y     Y   LP401
#
#        Wencalc Saletype Appraiser ID Income  Bldgros V  Mscbld V  Val30 SUM  \
# 0          NaN      NaN          NaN    NaN        NaN       NaN        NaN
# 1          NaN      NaN          NaN    NaN        NaN       NaN        NaN
# 2  21-MAY-2013      NaN          NaN    NaN        NaN       NaN        NaN
#
#    Areasum    FID  OBJECTID         ParcelID           Address  \
# 0      NaN  11306     12766  07 230000570315  7495 PHILLIPS RD
# 1      NaN  11306     12766  07 230000570315  7495 PHILLIPS RD
# 2      NaN  11306     12766  07 230000570315  7495 PHILLIPS RD
#
#                                Match_addr         X          Y  \
# 0  Phillips Dr SE, Atlanta, GA 30315, USA -84.35376  33.699902
# 1  Phillips Dr SE, Atlanta, GA 30315, USA -84.35376  33.699902
# 2  Phillips Dr SE, Atlanta, GA 30315, USA -84.35376  33.699902
#
#                MatchType_          FIPS  DistoCityc  TaxYear  AddrNumber  \
# 0  GEOMETRIC_CENTER route  131210000000   6819.2993     2023        7495
# 1  GEOMETRIC_CENTER route  131210000000   6819.2993     2023        7495
# 2  GEOMETRIC_CENTER route  131210000000   6819.2993     2023        7495
#
#    AddrPreDir AddrStreet AddrSuffix AddrPosDir AddrUntTyp AddrUnit  \
# 0         NaN   PHILLIPS         RD        NaN        NaN      NaN
# 1         NaN   PHILLIPS         RD        NaN        NaN      NaN
# 2         NaN   PHILLIPS         RD        NaN        NaN      NaN
#
#           Owner        OwnerAddr1         OwnerAddr2 TaxDist  TotAssess  \
# 0  HEPLER SEAN   7495 PHILLIPS RD  PALMETTO GA 30268      65      51560
# 1  HEPLER SEAN   7495 PHILLIPS RD  PALMETTO GA 30268      65      51560
# 2  HEPLER SEAN   7495 PHILLIPS RD  PALMETTO GA 30268      65      51560
#
#    LandAssess  ImprAssess  TotAppr  LandAppr  ImprAppr LUCode ClassCode  \
# 0        6080       45480   128900     15200    113700    101        R3
# 1        6080       45480   128900     15200    113700    101        R3
# 2        6080       45480   128900     15200    113700    101        R3
#
#    ExCode  LivUnits  LandAcres NbrHood  Subdiv SubdivNum SubdivLot SubdivBlck  \
# 0     NaN       1.0        1.0    7001     NaN       NaN       NaN        NaN
# 1     NaN       1.0        1.0    7001     NaN       NaN       NaN        NaN
# 2     NaN       1.0        1.0    7001     NaN       NaN       NaN        NaN
#
#          FeatureID  Shape__Area  Shape__Length         neighborhood
# 0  07 230000570315    45103.582      1005.9736  Thomasville Heights
# 1  07 230000570315    45103.582      1005.9736  Thomasville Heights
# 2  07 230000570315    45103.582      1005.9736  Thomasville Heights

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 91 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Taxyr                2264 non-null   string
#  1   Saledt: Year (YYYY)  2264 non-null   float64
#  2   Saledt: Month (Mon)  2264 non-null   object
#  3   Taxdist              2264 non-null   object
#  4   Parid                2264 non-null   object
#  5   Nbhd                 2264 non-null   object
#  6   Class                2264 non-null   object
#  7   Luc                  2264 non-null   object
#  8   Saledt               2264 non-null   object
#  9   Book                 2264 non-null   object
#  10  Page                 2264 non-null   object
#  11  SALES PRICE          2264 non-null   object
#  12  FAIR MARKET VALUE    2264 non-null   object
#  13  DEED TYPE            2264 non-null   object
#  14  Aprland              2264 non-null   object
#  15  Aprbldg              2264 non-null   object
#  16  Costval              2264 non-null   object
#  17  Saleval              2262 non-null   object
#  18  Who                  2264 non-null   object
#  19  Wen                  2264 non-null   object
#  20  GRANTOR              2264 non-null   object
#  21  GRANTEE              2264 non-null   object
#  22  Revcode              1316 non-null   float64
#  23  Reascd               1653 non-null   object
#  24  Adrpre               0 non-null      float64
#  25  Adrno                2264 non-null   float64
#  26  Adrdir               0 non-null      object
#  27  Adrstr               2264 non-null   object
#  28  Adrsuf               2264 non-null   object
#  29  Adrsuf2              2044 non-null   object
#  30  Cityname             2264 non-null   object
#  31  Unitno               17 non-null     object
#  32  Livunit              2151 non-null   float64
#  33  Calcacres            2260 non-null   float64
#  34  Zoning               2264 non-null   object
#  35  Notecd1              291 non-null    object
#  36  Notecd2              71 non-null     float64
#  37  Chgrsn               2153 non-null   object
#  38  Cur                  2264 non-null   object
#  39  Cur.1                2264 non-null   object
#  40  Whocalc              1068 non-null   object
#  41  Wencalc              1013 non-null   object
#  42  Saletype             1349 non-null   object
#  43  Appraiser ID         1664 non-null   object
#  44  Income               1664 non-null   object
#  45  Bldgros V            9 non-null      float64
#  46  Mscbld V             115 non-null    float64
#  47  Val30 SUM            1545 non-null   float64
#  48  Areasum              1548 non-null   float64
#  49  FID                  2264 non-null   int64
#  50  OBJECTID             2264 non-null   int64
#  51  ParcelID             2264 non-null   object
#  52  Address              2264 non-null   object
#  53  Match_addr           2264 non-null   object
#  54  X                    2264 non-null   float64
#  55  Y                    2264 non-null   float64
#  56  MatchType_           2264 non-null   object
#  57  FIPS                 2264 non-null   int64
#  58  DistoCityc           2264 non-null   float64
#  59  TaxYear              2264 non-null   int64
#  60  AddrNumber           2264 non-null   int64
#  61  AddrPreDir           0 non-null      float64
#  62  AddrStreet           2264 non-null   object
#  63  AddrSuffix           2264 non-null   object
#  64  AddrPosDir           2044 non-null   object
#  65  AddrUntTyp           8 non-null      object
#  66  AddrUnit             17 non-null     object
#  67  Owner                2264 non-null   object
#  68  OwnerAddr1           2264 non-null   object
#  69  OwnerAddr2           2264 non-null   object
#  70  TaxDist              2264 non-null   object
#  71  TotAssess            2264 non-null   int64
#  72  LandAssess           2264 non-null   int64
#  73  ImprAssess           2264 non-null   int64
#  74  TotAppr              2264 non-null   int64
#  75  LandAppr             2264 non-null   int64
#  76  ImprAppr             2264 non-null   int64
#  77  LUCode               2264 non-null   object
#  78  ClassCode            2264 non-null   object
#  79  ExCode               0 non-null      float64
#  80  LivUnits             2163 non-null   float64
#  81  LandAcres            2264 non-null   float64
#  82  NbrHood              2264 non-null   object
#  83  Subdiv               0 non-null      float64
#  84  SubdivNum            48 non-null     object
#  85  SubdivLot            63 non-null     object
#  86  SubdivBlck           0 non-null      object
#  87  FeatureID            2264 non-null   object
#  88  Shape__Area          2264 non-null   float64
#  89  Shape__Length        2264 non-null   float64
#  90  neighborhood         2264 non-null   object
# dtypes: float64(21), int64(11), object(58), string(1)
# memory usage: 1.6+ MB

# %%
parid_taxyr_dup = merged.duplicated(subset=['Parid', 'Taxyr']).sum()
print("Number of rows with the same ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(merged.index) * 100)
# Out:
# Number of rows with the same ['Parid', 'Taxyr']:  713
# Percent:  31.492932862190813

# %%
parid_taxyr_dup = nbhrs.duplicated(subset=['ParcelID', 'TaxYear']).sum()
print("Number of rows with the same ['Parid', 'Taxyr']: ", parid_taxyr_dup)
print("Percent: ", parid_taxyr_dup / len(nbhrs.index) * 100)
# Out:
# Number of rows with the same ['Parid', 'Taxyr']:  0
# Percent:  0.0

# %% [markdown]
# Just say a parcel has 1 building. But its a condo, and 2 of them sold in one year. We need to link the right sale data to each specific unit.

# %% [markdown]
# - Eliminate some variables.
# - Determine which variables change even for the same parcel; for variables that change that we want to keep- determine how to aggregate.
# - Use key: [Parid, Taxyr, SITUS Address, Unitno]?
# - Continue to use Taxyr?
# - Geocode
# - Owner address info is only in parcel data, not sale data. Therefore, it may not be updated at the same time as the sale.
#
# I need to figure out a unique key to merge parcel and sales data that allows for specific units in the same building to be sold.
# Identify the variables that change for the same Parid, Taxyr.
# Also need to figure out how to aggregate the variables that change when there are multiple buildings on one parcel.
# Merge this data
#
# How do we know about changing parcel IDs?

# %% [markdown]
# - Get geocoded full sales and parcel data

# %%
parcel_sales = pd.read_csv('../data/parcel_sales_fulton_merged.csv')
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_15472\2203077417.py:1: DtypeWarning: Columns (30,31,97,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   parcel_sales = pd.read_csv('../data/parcel_sales_fulton_merged.csv')

# %%
parcel_sales.head(3)
# Out:
#    Unnamed: 0  Taxyr            Parid Nbhd_x  SITUS Adrpre  SITUS Adrno  \
# 0           0   2011  06 036300010858   C207           NaN       8800.0
# 1           1   2011  06 036300020121   C207           NaN       8800.0
# 2           2   2011  06 036300040343   C207           NaN       8613.0
#
#   SITUS Adrdir SITUS Adrstr SITUS Adrsuf SITUS Adrsuf2 SITUS Cityname Class_x  \
# 0          NaN     DUNWOODY           PL           NaN  SANDY SPRINGS      C5
# 1          NaN     DUNWOODY           PL           NaN  SANDY SPRINGS      C5
# 2          NaN      ROSWELL           RD           NaN  SANDY SPRINGS      C3
#
#   Luc_x  Livunit_x  Calcacres_x Chgrsn_x Taxdist_x               Own1 Own2  \
# 0   2B1      210.0        18.17       MN        59         ROV VI LLC  NaN
# 1   2B1      142.0        11.33       MN        59         ROV VI LLC  NaN
# 2   3C3        0.0         0.98       MN        59  JAT PARTNERS LLLP  NaN
#
#   Careof  OWNER Adrno OWNER Adrdir OWNER Adrstr OWNER Adrsuf OWNER Adrsuf2  \
# 0    NaN      11755.0          NaN     WILSHIRE         BLVD           NaN
# 1    NaN      11755.0          NaN     WILSHIRE         BLVD           NaN
# 2    NaN       8613.0          NaN      ROSWELL           RD           NaN
#
#   OWNER Cityname Statecode Country Unitdesc Unitno_x   Zip1  Zip2 Reascd_x  \
# 0    LOS ANGELES        CA     NaN    SUITE     1670  90025   NaN       E1
# 1    LOS ANGELES        CA     NaN    SUITE     1670  90025   NaN       E1
# 2  SANDY SPRINGS        GA     NaN     BLDG        4  30350  1896       E0
#
#   Spcflg  Aprland_x  Aprbldg_x  Revcode_x Revreas    Revland    Revbldg  \
# 0    NaN  4200000.0  6150000.0        3.0     OVR  4200000.0  6150000.0
# 1    NaN  2840000.0  4160000.0        3.0     OVR  2840000.0  4160000.0
# 2    NaN  1002200.0   465300.0        3.0      70  1002200.0   465300.0
#
#        Revtot      Aprtot  Exmppct  Exmpval Cur_x  Areasum_x Bldnum   Effyr  \
# 0  10350000.0  10350000.0      NaN      0.0     Y   199611.0      1  1980.0
# 1   7000000.0   7000000.0      NaN      0.0     Y   134916.0      1  1980.0
# 2   1467500.0   1467500.0      NaN      0.0     Y     6460.0      1     NaN
#
#   Grade    Area  ...  Structure  Stories  BuildingCount  Saledt: Year (YYYY)  \
# 0     B  3317.0  ...      211.0      1.0           19.0               2010.0
# 1     B  5552.0  ...      211.0      1.0            8.0               2010.0
# 2    B-  2870.0  ...      353.0      1.0            2.0               2010.0
#
#    Saledt: Month (Mon)  Taxdist_y  Nbhd_y  Class_y  Luc_y       Saledt  \
# 0                  Nov         59    C207       C5    2B1  02-NOV-2010
# 1                  Nov         59    C207       C5    2B1  02-NOV-2010
# 2                  Mar         59    C207       C3    3C3  23-MAR-2010
#
#       Book   Page  SALES PRICE  FAIR MARKET VALUE  DEED TYPE  Aprland_y  \
# 0  49515.0  118.0   16,053,491         10,350,000         DP  4200000.0
# 1  49515.0  118.0   16,053,491          7,000,000         DP  2840000.0
# 2  48987.0  672.0            0          1,467,500         QC  1002200.0
#
#    Aprbldg_y     Costval Saleval        Who          Wen  \
# 0  6150000.0  14441300.0       M  TA_LPRICE  22-NOV-2010
# 1  4160000.0   9976100.0       M  TA_LPRICE  22-NOV-2010
# 2   465300.0   1467500.0       M  TA_LPRICE  30-SEP-2010
#
#                  GRANTOR            GRANTEE Revcode_y Reascd_y Adrpre   Adrno  \
# 0   ASLAN LEGACY KEY LLC         ROV VI LLC       3.0       E1    NaN  8800.0
# 1   ASLAN LEGACY KEY LLC         ROV VI LLC       3.0       E1    NaN  8800.0
# 2  THOMAS JAMES STARK JR  JAT PARTNERS LLLP       3.0       E0    NaN  8613.0
#
#   Adrdir    Adrstr Adrsuf Adrsuf2 Cityname Unitno_y Livunit_y  Calcacres_y  \
# 0    NaN  DUNWOODY     PL     NaN      FUL      NaN     210.0        18.17
# 1    NaN  DUNWOODY     PL     NaN      FUL     REAR     142.0        11.33
# 2    NaN   ROSWELL     RD     NaN      FUL      NaN       0.0         0.98
#
#   Zoning  Notecd1  Notecd2 Chgrsn_y Cur_y Cur.1 Whocalc Wencalc Saletype  \
# 0     AC      NaN      NaN       MN     Y     Y     NaN     NaN      NaN
# 1     AC      NaN      NaN       MN     Y     Y     NaN     NaN      NaN
# 2     C2      NaN      NaN       MN     Y     Y     NaN     NaN      NaN
#
#    Appraiser ID  Income Bldgros V Mscbld V  Val30 SUM Areasum_y
# 0           NaN     NaN       NaN      NaN        NaN       NaN
# 1           NaN     NaN       NaN      NaN        NaN       NaN
# 2           NaN     NaN       NaN      NaN        NaN       NaN
#
# [3 rows x 111 columns]

# %%
parcels_atl = pd.read_csv('../data/parcels_in_atl.csv')

# %%
parcels_atl = parcels_atl[['parcelid', 'x', 'y', 'NAME', 'geometry']]

# %%
parcels_atl.head(3)
# Out:
#           parcelid          x          y            NAME  \
# 0  06 033700050642 -84.403067  33.800487  Loring Heights
# 1  07 170001370069 -84.404044  33.792496  Loring Heights
# 2  07 170001370317 -84.404044  33.792496  Loring Heights
#
#                        geometry
# 0  POINT (-84.403067 33.800487)
# 1  POINT (-84.404044 33.792496)
# 2  POINT (-84.404044 33.792496)

# %%
parcel_geo = parcel_sales.merge(parcels_atl, left_on='Parid', right_on='parcelid', how='left')

# %%
parcel_geo
# Out:
#        Unnamed: 0  Taxyr            Parid Nbhd_x  SITUS Adrpre  SITUS Adrno  \
# 0               0   2011  06 036300010858   C207           NaN       8800.0
# 1               1   2011  06 036300020121   C207           NaN       8800.0
# 2               2   2011  06 036300040343   C207           NaN       8613.0
# 3               3   2011  06 036300040343   C207           NaN       8613.0
# 4               4   2011  06 036300040343   C207           NaN       8613.0
# ...           ...    ...              ...    ...           ...          ...
# 29485       29485   2022  22 546012611444   C104           NaN       3225.0
# 29486       29486   2022  22 546012620577   C104           NaN      12150.0
# 29487       29487   2022  22 546012620577   C104           NaN      12150.0
# 29488       29488   2022  22 546012621484   C108           NaN      12130.0
# 29489       29489   2022  22 546012621484   C108           NaN      12130.0
#
#       SITUS Adrdir SITUS Adrstr SITUS Adrsuf SITUS Adrsuf2 SITUS Cityname  \
# 0              NaN     DUNWOODY           PL           NaN  SANDY SPRINGS
# 1              NaN     DUNWOODY           PL           NaN  SANDY SPRINGS
# 2              NaN      ROSWELL           RD           NaN  SANDY SPRINGS
# 3              NaN      ROSWELL           RD           NaN  SANDY SPRINGS
# 4              NaN      ROSWELL           RD           NaN  SANDY SPRINGS
# ...            ...          ...          ...           ...            ...
# 29485          NaN  WEBB BRIDGE           RD           NaN     ALPHARETTA
# 29486          NaN       MORRIS           RD           NaN     ALPHARETTA
# 29487          NaN       MORRIS           RD           NaN     ALPHARETTA
# 29488          NaN       MORRIS           RD           NaN     ALPHARETTA
# 29489          NaN       MORRIS           RD           NaN     ALPHARETTA
#
#       Class_x Luc_x  Livunit_x  Calcacres_x Chgrsn_x Taxdist_x  \
# 0          C5   2B1      210.0       18.170       MN        59
# 1          C5   2B1      142.0       11.330       MN        59
# 2          C3   3C3        0.0        0.980       MN        59
# 3          C3   3C3        0.0        0.980       MN        59
# 4          C3   3C3        0.0        0.980       MN        59
# ...       ...   ...        ...          ...      ...       ...
# 29485      C4   300        0.0        6.519       MN        10
# 29486      C4   300        0.0        7.736       MN        10
# 29487      C4   300        0.0        7.736       MN        10
# 29488      C3   300        0.0        0.560       MN        10
# 29489      C3   300        0.0        0.560       MN        10
#
#                                          Own1 Own2 Careof  OWNER Adrno  \
# 0                                  ROV VI LLC  NaN    NaN      11755.0
# 1                                  ROV VI LLC  NaN    NaN      11755.0
# 2                           JAT PARTNERS LLLP  NaN    NaN       8613.0
# 3                           JAT PARTNERS LLLP  NaN    NaN       8613.0
# 4                           JAT PARTNERS LLLP  NaN    NaN       8613.0
# ...                                       ...  ...    ...          ...
# 29485        ALPHARETTA HOTEL INVESTMENTS LLC  NaN    NaN       1000.0
# 29486  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC  NaN    NaN         26.0
# 29487  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC  NaN    NaN         26.0
# 29488  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC  NaN    NaN         26.0
# 29489  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC  NaN    NaN         26.0
#
#       OWNER Adrdir  OWNER Adrstr OWNER Adrsuf OWNER Adrsuf2 OWNER Cityname  \
# 0              NaN      WILSHIRE         BLVD           NaN    LOS ANGELES
# 1              NaN      WILSHIRE         BLVD           NaN    LOS ANGELES
# 2              NaN       ROSWELL           RD           NaN  SANDY SPRINGS
# 3              NaN       ROSWELL           RD           NaN  SANDY SPRINGS
# 4              NaN       ROSWELL           RD           NaN  SANDY SPRINGS
# ...            ...           ...          ...           ...            ...
# 29485          NaN  TOWNE CENTER         BLVD           NaN         POOLER
# 29486          NaN        MILTON          AVE           NaN     ALPHARETTA
# 29487          NaN        MILTON          AVE           NaN     ALPHARETTA
# 29488          NaN        MILTON          AVE           NaN     ALPHARETTA
# 29489          NaN        MILTON          AVE           NaN     ALPHARETTA
#
#       Statecode Country Unitdesc Unitno_x     Zip1  Zip2 Reascd_x Spcflg  \
# 0            CA     NaN    SUITE     1670    90025   NaN       E1    NaN
# 1            CA     NaN    SUITE     1670    90025   NaN       E1    NaN
# 2            GA     NaN     BLDG        4    30350  1896       E0    NaN
# 3            GA     NaN     BLDG        4    30350  1896       E0    NaN
# 4            GA     NaN     BLDG        4    30350  1896       E0    NaN
# ...         ...     ...      ...      ...      ...   ...      ...    ...
# 29485        GA     NaN      STE      503  31322.0   NaN       CO    NaN
# 29486        GA     NaN      NaN      NaN  30009.0   NaN       H2    NaN
# 29487        GA     NaN      NaN      NaN  30009.0   NaN       H2    NaN
# 29488        GA     NaN      NaN      NaN  30009.0   NaN       E2    NaN
# 29489        GA     NaN      NaN      NaN  30009.0   NaN       E2    NaN
#
#        Aprland_x  Aprbldg_x  Revcode_x Revreas    Revland    Revbldg  \
# 0      4200000.0  6150000.0        3.0     OVR  4200000.0  6150000.0
# 1      2840000.0  4160000.0        3.0     OVR  2840000.0  4160000.0
# 2      1002200.0   465300.0        3.0      70  1002200.0   465300.0
# 3      1002200.0   465300.0        3.0      70  1002200.0   465300.0
# 4      1002200.0   465300.0        3.0      70  1002200.0   465300.0
# ...          ...        ...        ...     ...        ...        ...
# 29485  2281700.0        0.0        1.0     NaN        NaN        NaN
# 29486   105000.0   223300.0        3.0     OVR   105000.0   223300.0
# 29487   105000.0   223300.0        3.0     OVR   105000.0   223300.0
# 29488   168500.0        0.0        3.0     OVR   168500.0        0.0
# 29489   168500.0        0.0        3.0     OVR   168500.0        0.0
#
#            Revtot      Aprtot  Exmppct  Exmpval Cur_x  Areasum_x Bldnum  \
# 0      10350000.0  10350000.0      NaN      0.0     Y   199611.0      1
# 1       7000000.0   7000000.0      NaN      0.0     Y   134916.0      1
# 2       1467500.0   1467500.0      NaN      0.0     Y     6460.0      1
# 3       1467500.0   1467500.0      NaN      0.0     Y     6460.0      1
# 4       1467500.0   1467500.0      NaN      0.0     Y     6460.0      1
# ...           ...         ...      ...      ...   ...        ...    ...
# 29485         NaN   2281700.0      NaN      0.0     Y        0.0    NaN
# 29486    328300.0    328300.0      NaN      0.0     Y        0.0    NaN
# 29487    328300.0    328300.0      NaN      0.0     Y        0.0    NaN
# 29488    168500.0    168500.0      NaN      0.0     Y        0.0    NaN
# 29489    168500.0    168500.0      NaN      0.0     Y        0.0    NaN
#
#         Effyr Grade    Area  ...  Taxdist_y  Nbhd_y  Class_y  Luc_y  \
# 0      1980.0     B  3317.0  ...         59    C207       C5    2B1
# 1      1980.0     B  5552.0  ...         59    C207       C5    2B1
# 2         NaN    B-  2870.0  ...         59    C207       C3    3C3
# 3         NaN    B-  2870.0  ...         59    C207       C3    3C3
# 4         NaN    B-  2870.0  ...         59    C207       C3    3C3
# ...       ...   ...     ...  ...        ...     ...      ...    ...
# 29485     NaN   NaN     NaN  ...         10    C104       C4    300
# 29486     NaN   NaN     NaN  ...         10    C104       C4    300
# 29487     NaN   NaN     NaN  ...         10    C104       C4    300
# 29488     NaN   NaN     NaN  ...         10    C108       C3    300
# 29489     NaN   NaN     NaN  ...         10    C108       C3    300
#
#             Saledt     Book   Page  SALES PRICE  FAIR MARKET VALUE  DEED TYPE  \
# 0      02-NOV-2010  49515.0  118.0   16,053,491         10,350,000         DP
# 1      02-NOV-2010  49515.0  118.0   16,053,491          7,000,000         DP
# 2      23-MAR-2010  48987.0  672.0            0          1,467,500         QC
# 3      25-OCT-2010  49497.0  567.0            0          1,467,500         QC
# 4      06-JUL-2010  49502.0   46.0            0          1,467,500         DP
# ...            ...      ...    ...          ...                ...        ...
# 29485  02-SEP-2021  64421.0  546.0            0          2,281,700         QC
# 29486  17-AUG-2021  64421.0  116.0            0            328,300         LW
# 29487  17-AUG-2021  64421.0  114.0            0            328,300         LW
# 29488  17-AUG-2021  64421.0  114.0            0            168,500         LW
# 29489  17-AUG-2021  64421.0  116.0            0            168,500         LW
#
#        Aprland_y  Aprbldg_y     Costval  Saleval        Who          Wen  \
# 0      4200000.0  6150000.0  14441300.0        M  TA_LPRICE  22-NOV-2010
# 1      2840000.0  4160000.0   9976100.0        M  TA_LPRICE  22-NOV-2010
# 2      1002200.0   465300.0   1467500.0        M  TA_LPRICE  30-SEP-2010
# 3      1002200.0   465300.0   1467500.0        M  TA_LPRICE  16-NOV-2010
# 4      1002200.0   465300.0   1467500.0        5  TA_LPRICE  16-NOV-2010
# ...          ...        ...         ...      ...        ...          ...
# 29485  2,281,700          0   2,281,700        T  TA_WBRITT  24-FEB-2022
# 29486    105,000    223,300   3,607,800        M  TA_WBRITT  24-FEB-2022
# 29487    105,000    223,300   3,607,800        M  TA_JBANKS  08-MAR-2022
# 29488    168,500          0     168,500        M  TA_JBANKS  08-MAR-2022
# 29489    168,500          0     168,500        M  TA_WBRITT  24-FEB-2022
#
#                                        GRANTOR  \
# 0                         ASLAN LEGACY KEY LLC
# 1                         ASLAN LEGACY KEY LLC
# 2                        THOMAS JAMES STARK JR
# 3                         THOMAS MICHAEL BARRY
# 4                          SMITH KIYOKO MIQUNO
# ...                                        ...
# 29485                           GANDHI KRISHAN
# 29486  WEBB BRIDGE INVESTMENTS LLC, A DELAWARE
# 29487  WEBB BRIDGE INVESTMENTS LLC, A DELAWARE
# 29488              WEBB BRIDGE INVESTMENTS LLC
# 29489  WEBB BRIDGE INVESTMENTS LLC, A DELAWARE
#
#                                       GRANTEE Revcode_y Reascd_y Adrpre  \
# 0                                  ROV VI LLC       3.0       E1    NaN
# 1                                  ROV VI LLC       3.0       E1    NaN
# 2                           JAT PARTNERS LLLP       3.0       E0    NaN
# 3                           JAT PARTNERS LLLP       3.0       E0    NaN
# 4            ROTHMAN SUSAN M & MARC KANNE LLC       3.0       E0    NaN
# ...                                       ...       ...      ...    ...
# 29485        ALPHARETTA HOTEL INVESTMENTS LLC       1.0       CO    NaN
# 29486          WEBB BRIDGE INVESTMENTS II LLC       3.0       H2    NaN
# 29487  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC       3.0       H2    NaN
# 29488  MAYFAIR AT WEBB BRIDGE ASSOCIATION INC       3.0       E2    NaN
# 29489          WEBB BRIDGE INVESTMENTS II LLC       3.0       E2    NaN
#
#          Adrno  Adrdir       Adrstr Adrsuf Adrsuf2    Cityname Unitno_y  \
# 0       8800.0     NaN     DUNWOODY     PL     NaN         FUL      NaN
# 1       8800.0     NaN     DUNWOODY     PL     NaN         FUL     REAR
# 2       8613.0     NaN      ROSWELL     RD     NaN         FUL      NaN
# 3       8613.0     NaN      ROSWELL     RD     NaN         FUL      NaN
# 4       8613.0     NaN      ROSWELL     RD     NaN         FUL      NaN
# ...        ...     ...          ...    ...     ...         ...      ...
# 29485   3225.0     NaN  WEBB BRIDGE     RD     NaN  ALPHARETTA      NaN
# 29486  12150.0     NaN       MORRIS     RD     NaN  ALPHARETTA      NaN
# 29487  12150.0     NaN       MORRIS     RD     NaN  ALPHARETTA      NaN
# 29488  12130.0     NaN       MORRIS     RD     NaN  ALPHARETTA      NaN
# 29489  12130.0     NaN       MORRIS     RD     NaN  ALPHARETTA      NaN
#
#       Livunit_y Calcacres_y Zoning Notecd1 Notecd2 Chgrsn_y  Cur_y Cur.1  \
# 0         210.0      18.170     AC     NaN     NaN       MN      Y     Y
# 1         142.0      11.330     AC     NaN     NaN       MN      Y     Y
# 2           0.0       0.980     C2     NaN     NaN       MN      Y     Y
# 3           0.0       0.980     C2     NaN     NaN       MN      Y     Y
# 4           0.0       0.980     C2     NaN     NaN       MN      Y     Y
# ...         ...         ...    ...     ...     ...      ...    ...   ...
# 29485       0.0       6.519     OI      23     NaN       MN      Y     Y
# 29486       0.0       7.736     OI     NaN     NaN       MN      Y     Y
# 29487       0.0       7.736     OI     NaN     NaN       MN      Y     Y
# 29488       0.0       0.560     OI     NaN     NaN       MN      Y     Y
# 29489       0.0       0.560     OI     NaN     NaN       MN      Y     Y
#
#        Whocalc  Wencalc Saletype Appraiser ID Income Bldgros V Mscbld V  \
# 0          NaN      NaN      NaN          NaN    NaN       NaN      NaN
# 1          NaN      NaN      NaN          NaN    NaN       NaN      NaN
# 2          NaN      NaN      NaN          NaN    NaN       NaN      NaN
# 3          NaN      NaN      NaN          NaN    NaN       NaN      NaN
# 4          NaN      NaN      NaN          NaN    NaN       NaN      NaN
# ...        ...      ...      ...          ...    ...       ...      ...
# 29485      NaN      NaN      NaN        313.0      0       NaN      NaN
# 29486      NaN      NaN      NaN        313.0      0       NaN      NaN
# 29487      NaN      NaN      NaN        313.0      0       NaN      NaN
# 29488      NaN      NaN      NaN        313.0      0       NaN      NaN
# 29489      NaN      NaN      NaN        313.0      0       NaN      NaN
#
#        Val30 SUM  Areasum_y  parcelid   x   y  NAME geometry
# 0            NaN        NaN       NaN NaN NaN   NaN      NaN
# 1            NaN        NaN       NaN NaN NaN   NaN      NaN
# 2            NaN        NaN       NaN NaN NaN   NaN      NaN
# 3            NaN        NaN       NaN NaN NaN   NaN      NaN
# 4            NaN        NaN       NaN NaN NaN   NaN      NaN
# ...          ...        ...       ...  ..  ..   ...      ...
# 29485  2281700.0        0.0       NaN NaN NaN   NaN      NaN
# 29486  3607800.0        0.0       NaN NaN NaN   NaN      NaN
# 29487  3607800.0        0.0       NaN NaN NaN   NaN      NaN
# 29488   168500.0        0.0       NaN NaN NaN   NaN      NaN
# 29489   168500.0        0.0       NaN NaN NaN   NaN      NaN
#
# [29490 rows x 116 columns]

# %%
parcel_geo[parcel_geo['NAME'] == 'South Atlanta']
# Out:
#        Unnamed: 0  Taxyr            Parid Nbhd_x  SITUS Adrpre  SITUS Adrno  \
# 949           949   2011  14 0056  LL0070   C901           NaN       1293.0
# 950           950   2011  14 005700090046   C901           NaN       1534.0
# 952           952   2011  14 005700090293   C901           NaN       1518.0
# 2399         2399   2011  22 482512690078   C103           NaN         41.0
# 2400         2400   2011  22 482512690078   C103           NaN         41.0
# ...           ...    ...              ...    ...           ...          ...
# 26299       26299   2022  14 005700090285   C901           NaN       1515.0
# 26300       26300   2022  14 005700120124   C901           NaN       1553.0
# 26301       26301   2022  14 005700120124   C901           NaN       1553.0
# 27668       27668   2022  14 013100030695   C909           NaN       1296.0
# 29391       29391   2022  22 466212710765  2021C           NaN         14.0
#
#       SITUS Adrdir SITUS Adrstr SITUS Adrsuf SITUS Adrsuf2 SITUS Cityname  \
# 949            NaN        MARCY           ST            SE        ATLANTA
# 950            NaN    JONESBORO           RD            SE        ATLANTA
# 952            NaN    JONESBORO           RD            SE        ATLANTA
# 2399           NaN       MILTON          AVE           NaN     ALPHARETTA
# 2400           NaN       MILTON          AVE           NaN     ALPHARETTA
# ...            ...          ...          ...           ...            ...
# 26299          NaN     LAKEWOOD          AVE            SE        ATLANTA
# 26300          NaN    JONESBORO           RD            SE        ATLANTA
# 26301          NaN    JONESBORO           RD            SE        ATLANTA
# 27668          NaN       MARTIN           ST           NaN     EAST POINT
# 29391          NaN       MILTON          AVE           NaN     ALPHARETTA
#
#       Class_x Luc_x  Livunit_x  Calcacres_x Chgrsn_x Taxdist_x  \
# 949        C3   2D1       16.0       0.5600       MN       05T
# 950        I3   398        NaN       0.4563       MN         5
# 952        C3   374        NaN       0.2970       RV         5
# 2399       C3   353        NaN       0.1322       RV        10
# 2400       C3   353        NaN       0.1322       RV        10
# ...       ...   ...        ...          ...      ...       ...
# 26299      C3   300        0.0       0.1647       MN         5
# 26300      C3   373        NaN       0.2755       RV         5
# 26301      C3   373        NaN       0.2755       RV         5
# 27668      C3   300        0.0       0.3600       MN        20
# 29391      R3   100        0.0       0.3120       RV        10
#
#                                    Own1       Own2                     Careof  \
# 949                ARS MARCY STREET LLC        NaN                        NaN
# 950      BRANCH BANKING & TRUST COMPANY        NaN  PROP TAX COMPLIANCE GROUP
# 952                     LOU QINGXIANG &  WU HUIQIN                        NaN
# 2399            SUMMIT SPRINGS FARM LLC        NaN                        NaN
# 2400            SUMMIT SPRINGS FARM LLC        NaN                        NaN
# ...                                 ...        ...                        ...
# 26299  0 LAKEWOOD AVENUE LAND TRUST THE        NaN                        NaN
# 26300                  BAWRE REALTY LLC        NaN                        NaN
# 26301                  BAWRE REALTY LLC        NaN                        NaN
# 27668      16TH GROUP OF PROPERTIES LLC        NaN                        NaN
# 29391                        KANE JAMES        NaN                        NaN
#
#        OWNER Adrno OWNER Adrdir  OWNER Adrstr OWNER Adrsuf OWNER Adrsuf2  \
# 949          619.0          NaN      EDGEWOOD          AVE           NaN
# 950            NaN          NaN  P.O. BOX 167          NaN           NaN
# 952          400.0            W     PEACHTREE           ST            NW
# 2399        1385.0          NaN        SUMMIT           RD           NaN
# 2400        1385.0          NaN        SUMMIT           RD           NaN
# ...            ...          ...           ...          ...           ...
# 26299       2551.0          NaN  HIDDEN HILLS           DR           NaN
# 26300       1553.0          NaN     JONESBORO           RD            SE
# 26301       1553.0          NaN     JONESBORO           RD            SE
# 27668       2754.0          NaN        BODDIE           PL           NaN
# 29391       1009.0          NaN    WINDERMERE         XING           NaN
#
#       OWNER Cityname Statecode Country Unitdesc Unitno_x     Zip1  Zip2  \
# 949          ATLANTA        GA     NaN    SUITE      300    30312   NaN
# 950    WINSTON SALEM        NC     NaN      NaN      NaN    27102   167
# 952          ATLANTA        GA     NaN      NaN    #1411    30308  3548
# 2399      ALPHARETTA        GA     NaN      NaN      NaN    30004   NaN
# 2400      ALPHARETTA        GA     NaN      NaN      NaN    30004   NaN
# ...              ...       ...     ...      ...      ...      ...   ...
# 26299       MARIETTA        GA     NaN      NaN      NaN  30066.0   NaN
# 26300        ATLANTA        GA     NaN      NaN      NaN  30315.0   NaN
# 26301        ATLANTA        GA     NaN      NaN      NaN  30315.0   NaN
# 27668         DULUTH        GA     NaN      NaN      NaN  30097.0   NaN
# 29391        CUMMING        GA     NaN      NaN      NaN  30041.0   NaN
#
#       Reascd_x Spcflg  Aprland_x  Aprbldg_x  Revcode_x Revreas   Revland  \
# 949         S1    NaN    24000.0    26000.0        3.0     OVR   24000.0
# 950        NaN    NaN   129000.0    68400.0        4.0     NaN  143300.0
# 952         SB    NaN    43900.0    35100.0        3.0     NaN   43900.0
# 2399        SB    NaN    64300.0   225700.0        3.0     NaN   64300.0
# 2400        SB    NaN    64300.0   225700.0        3.0     NaN   64300.0
# ...        ...    ...        ...        ...        ...     ...       ...
# 26299      NaN    NaN    24300.0        0.0        1.0     NaN       NaN
# 26300       CO    NaN   102400.0    89600.0        4.0     NaN       NaN
# 26301       CO    NaN   102400.0    89600.0        4.0     NaN       NaN
# 27668       CO    NaN    65900.0        0.0        1.0     NaN   65900.0
# 29391        0    NaN    77000.0        0.0        1.0      20       NaN
#
#         Revbldg    Revtot    Aprtot  Exmppct  Exmpval Cur_x  Areasum_x Bldnum  \
# 949     26000.0   50000.0   50000.0      NaN      0.0     Y     9152.0      1
# 950     24500.0  167800.0  197400.0      NaN      0.0     Y     7068.0      1
# 952     35100.0   79000.0   79000.0      NaN      0.0     Y     5856.0      1
# 2399   225700.0  290000.0  290000.0      NaN      0.0     Y     6164.0      1
# 2400   225700.0  290000.0  290000.0      NaN      0.0     Y     6164.0      1
# ...         ...       ...       ...      ...      ...   ...        ...    ...
# 26299       NaN       NaN   24300.0      NaN      0.0     Y        0.0    NaN
# 26300       NaN       NaN  192000.0      NaN      0.0     Y     2224.0      1
# 26301       NaN       NaN  192000.0      NaN      0.0     Y     2224.0      1
# 27668       0.0   65900.0   65900.0      NaN      0.0     Y        0.0    NaN
# 29391       0.0       0.0   77000.0      NaN      0.0     Y        0.0    NaN
#
#         Effyr Grade    Area  ...  Taxdist_y  Nbhd_y  Class_y  Luc_y  \
# 949    1950.0     C  2392.0  ...        05T    C901       C3    2D1
# 950       NaN     D  1400.0  ...         05    C901       I3    398
# 952       NaN    C-   640.0  ...         05    C901       C3    374
# 2399      NaN    C-  1726.0  ...         10    C103       C3    353
# 2400      NaN    C-  1726.0  ...         10    C103       C3    353
# ...       ...   ...     ...  ...        ...     ...      ...    ...
# 26299     NaN   NaN     NaN  ...         05    C901       C3    300
# 26300     NaN    C-   780.0  ...         05    C901       C3    373
# 26301     NaN    C-   780.0  ...         05    C901       C3    373
# 27668     NaN   NaN     NaN  ...         20    C909       C3    300
# 29391     NaN   NaN     NaN  ...         10   2021C       R3    100
#
#             Saledt     Book   Page  SALES PRICE  FAIR MARKET VALUE  DEED TYPE  \
# 949    21-APR-2010  48974.0  383.0       50,000            120,000         QC
# 950    07-SEP-2010  46373.0  651.0      160,000            197,400         DP
# 952    12-AUG-2010  49344.0  616.0       79,000             79,000         WD
# 2399   05-MAR-2010  48888.0  488.0            0            290,000         OT
# 2400   05-MAR-2010  48888.0  493.0      290,000            290,000         LW
# ...            ...      ...    ...          ...                ...        ...
# 26299  14-JUL-2021  64191.0  501.0            0             24,300         WD
# 26300  01-JUN-2021  63868.0  326.0            0            192,000         QC
# 26301  01-JUN-2021  63868.0  322.0      200,000            192,000         LW
# 27668  30-NOV-2021  64918.0  402.0       10,000             65,900         LW
# 29391  29-MAR-2021  63500.0  596.0      260,000             77,000         LW
#
#        Aprland_y  Aprbldg_y   Costval  Saleval         Who          Wen  \
# 949      24000.0    96000.0  466300.0        5  TA_EDASILV  28-MAR-2011
# 950     129000.0    68400.0  163400.0        5   TA_TJONES  29-SEP-2010
# 952      43900.0    35100.0  189700.0        0  TA_EDASILV  15-APR-2011
# 2399     64300.0   225700.0  529500.0        T  TA_SWILLIN  22-JUN-2010
# 2400     64300.0   225700.0  529500.0       RE         CLT  04-JAN-2011
# ...          ...        ...       ...      ...         ...          ...
# 26299     24,300          0    24,300        G   TA_VCLARK  08-FEB-2022
# 26300    102,400     89,600   185,700        T  TA_BWILCOX  28-DEC-2021
# 26301    102,400     89,600   185,700        0  TA_TBRIDGE  21-JAN-2022
# 27668     65,900          0    65,900        P  TA_JSMASHU  25-APR-2022
# 29391     77,000          0    77,000        P  TA_JWASHIN  20-APR-2022
#
#                                         GRANTOR                       GRANTEE  \
# 949               O'HALLORAN, RECEIVER KEVIN T.          ARS MARCY STREET LLC
# 950             LEGACY DEV INVESTMENT GROUP LLC     BRANCH BANKING & TRUST CO
# 952                   WEATHERBY JOYCE GWENDOLYN               LOU QINGXIANG &
# 2399   FDIC, AS RECEIVER FOR SECURITY BANK OF N    STATE BANK & TRUST COMPANY
# 2400               STATE BANK AND TRUST COMPANY       SUMMIT SPRINGS FARM LLC
# ...                                         ...                           ...
# 26299                           TODD ROBERT E &    ESTATE OF HELEN MARIE KEMP
# 26300                         MERKERSON PHYLLIS              BAWRE REALTY LLC
# 26301                         MERKERSON PHYLLIS              BAWRE REALTY LLC
# 27668  CAWTHON-HOLLUMS PROPERTIES, INC., A GEOR  16TH GROUP OF PROPERTIES LLC
# 29391                          FORREST ROBERT E                    KANE JAMES
#
#       Revcode_y Reascd_y Adrpre   Adrno  Adrdir     Adrstr Adrsuf Adrsuf2  \
# 949         3.0       E1    NaN  1293.0     NaN      MARCY     ST      SE
# 950         4.0      NaN    NaN  1534.0     NaN  JONESBORO     RD      SE
# 952         3.0       SB    NaN  1518.0     NaN  JONESBORO     RD      SE
# 2399        3.0       SB    NaN    41.0     NaN     MILTON    AVE     NaN
# 2400        3.0       SB    NaN    41.0     NaN     MILTON    AVE     NaN
# ...         ...      ...    ...     ...     ...        ...    ...     ...
# 26299       1.0      NaN    NaN  1515.0     NaN   LAKEWOOD    AVE      SE
# 26300       4.0       CO    NaN  1553.0     NaN  JONESBORO     RD      SE
# 26301       4.0       CO    NaN  1553.0     NaN  JONESBORO     RD      SE
# 27668       1.0       CO    NaN  1296.0     NaN     MARTIN     ST     NaN
# 29391       1.0       00    NaN    14.0     NaN     MILTON    AVE     NaN
#
#          Cityname Unitno_y Livunit_y Calcacres_y Zoning Notecd1 Notecd2  \
# 949           ATL      NaN      16.0      0.5600     R5    12.0     NaN
# 950           ATL      NaN       NaN      0.4563     I1     NaN     NaN
# 952           ATL      NaN       NaN      0.2970     I1     NaN     NaN
# 2399          ALP      NaN       NaN      0.1322     AG     NaN     NaN
# 2400          ALP      NaN       NaN      0.1322     AG     NaN     NaN
# ...           ...      ...       ...         ...    ...     ...     ...
# 26299     ATLANTA      NaN       0.0      0.1647    R4A      22     NaN
# 26300     ATLANTA      NaN       NaN      0.2755     R4     NaN     NaN
# 26301     ATLANTA      NaN       NaN      0.2755     R4     NaN     NaN
# 27668  EAST POINT      NaN       0.0      0.3600     R4     NaN     NaN
# 29391  ALPHARETTA      NaN       0.0      0.3120    R15      23     NaN
#
#       Chgrsn_y  Cur_y Cur.1  Whocalc      Wencalc Saletype Appraiser ID  \
# 949         MN      Y     Y      NaN          NaN      NaN          NaN
# 950         MN      Y     Y      NaN          NaN      NaN          NaN
# 952         RV      Y     Y      NaN          NaN      NaN          NaN
# 2399        RV      Y     Y      NaN          NaN      NaN          NaN
# 2400        RV      Y     Y      NaN          NaN      NaN          NaN
# ...        ...    ...   ...      ...          ...      ...          ...
# 26299       MN      Y     Y    LP401  01-MAR-2022        1        127.0
# 26300       RV      Y     Y      NaN          NaN      NaN        127.0
# 26301       RV      Y     Y      NaN          NaN        2        127.0
# 27668       MN      Y     Y      NaN          NaN        1        183.0
# 29391       RV      Y     Y    LP401  29-APR-2022        1         13.0
#
#         Income Bldgros V Mscbld V Val30 SUM  Areasum_y         parcelid  \
# 949        NaN       NaN      NaN       NaN        NaN  14 0056  LL0070
# 950        NaN       NaN      NaN       NaN        NaN  14 005700090046
# 952        NaN       NaN      NaN       NaN        NaN  14 005700090293
# 2399       NaN       NaN      NaN       NaN        NaN  22 482512690078
# 2400       NaN       NaN      NaN       NaN        NaN  22 482512690078
# ...        ...       ...      ...       ...        ...              ...
# 26299        0       NaN      NaN   24300.0        0.0  14 005700090285
# 26300  192,000       NaN      NaN  192000.0     2224.0  14 005700120124
# 26301  192,000       NaN      NaN  192000.0     2224.0  14 005700120124
# 27668        0       NaN      NaN   65900.0        0.0  14 013100030695
# 29391        0       NaN      NaN   77000.0        0.0  22 466212710765
#
#                x          y           NAME                      geometry
# 949   -84.386669  33.719097  South Atlanta  POINT (-84.386669 33.719097)
# 950   -84.382321  33.712269  South Atlanta  POINT (-84.382321 33.712269)
# 952   -84.382460  33.712760  South Atlanta    POINT (-84.38246 33.71276)
# 2399  -84.384690  33.711250  South Atlanta    POINT (-84.38469 33.71125)
# 2400  -84.384690  33.711250  South Atlanta    POINT (-84.38469 33.71125)
# ...          ...        ...            ...                           ...
# 26299 -84.381044  33.713048  South Atlanta  POINT (-84.381044 33.713048)
# 26300 -84.381830  33.710667  South Atlanta   POINT (-84.38183 33.710667)
# 26301 -84.381830  33.710667  South Atlanta   POINT (-84.38183 33.710667)
# 27668 -84.383897  33.719087  South Atlanta  POINT (-84.383897 33.719087)
# 29391 -84.382716  33.711613  South Atlanta  POINT (-84.382716 33.711613)
#
# [119 rows x 116 columns]

# %%
parcel_geo.to_csv('parcel_sales_geo.csv')
