# %% [markdown]
# # Business Registry Data Exploratory Data Analysis

# %%
import pandas as pd
import csv
pd.options.display.max_columns = 999

# %%
b_entity = pd.read_csv('../data/business/BizEntity.txt',
                       sep='\t',
                       encoding='latin',
                       engine='python',
                       quoting=csv.QUOTE_NONE)

# %%
b_addr = pd.read_csv('../data/business/BizEntityAddress.txt',
                     sep='\t',
                     encoding='latin',
                     engine='python',
                     quoting=csv.QUOTE_NONE)

# %%
entity_cols = ['BusinessId', 'BusinessName', 'BusinessTypeDesc',
               'ForeignState', 'ForeignCountry', 'EntityStatus',
               'Good Standing', 'NAICSCODE']
addr_cols = ['BusinessId','StreetAddress1', 'StreetAddress2',
             'City', 'State', 'Zip', 'Country']

# %% [markdown]
# ### Create a merged df called registry with the useful columns from the separate business registry files.
#
# Contains Business Name and Address information.

# %%
registry = b_entity[entity_cols].merge(b_addr[addr_cols],
                                       how='left',
                                       on='BusinessId')

# %% [markdown]
# ### Create a column called Adrno to speed up fuzzy matching

# %%
registry['Adrno'] = registry['StreetAddress1'].str.extract('(\d+)')

# %%
registry['Adrno'].head(5)
# Out:
# 0     310
# 1    4426
# 2    3014
# 3    1309
# 4      36
# Name: Adrno, dtype: object

# %% [markdown]
# There are some address numbers that are NaN because companies write "One" instead of 1, or they did not provide an address number

# %%
registry[registry['Adrno'].isna()].head(3)
# Out:
#      BusinessId                       BusinessName  \
# 100         101         VERIZON WIRELESS (VAW) LLC
# 116         117  PRESIDIO TECHNOLOGY CAPITAL,  LLC
# 147         148         THE MARTENSON LAW FIRM LLP
#
#                        BusinessTypeDesc ForeignState ForeignCountry  \
# 100   Foreign Limited Liability Company     Delaware            NaN
# 116  Domestic Limited Liability Company          NaN            NaN
# 147        Domestic Limited Partnership          NaN            NaN
#
#           EntityStatus  Good Standing NAICSCODE   StreetAddress1  \
# 100          Withdrawn              0       NaN  One Verizon Way
# 116  Active/Compliance              1       NaN       TWO SUN CT
# 147               Void              0       NaN              NaN
#
#     StreetAddress2           City State    Zip        Country Adrno
# 100            NaN  Basking Ridge    NJ  07920  United States   NaN
# 116            NaN       NORCROSS    GA  30092  United States   NaN
# 147            NaN            NaN   NaN    NaN  United States   NaN

# %%
len(registry[registry['Adrno'].isna()].index)
# Out:
# 121939

# %% [markdown]
# ### Investigate Zip column since that will also be used to speed up fuzzy matching

# %% [markdown]
# How many businesses in the zipcodes with the most registrants? This will let us know if we need to narrow down the search space even further from zip...
#
# With fuzzy matching, each value in the search space (e.g. properties owned by an owner with that zip) needs to be compared with zip in the registry data.

# %%
registry.groupby(['Zip'])['Zip'] \
        .count() \
        .sort_values(ascending=False) \
        .head(10)
# Out:
# Zip
# 30339    38854
# 30328    36234
# 30305    34206
# 30309    31651
# 30024    31598
# 30076    30182
# 30318    30169
# 30096    30093
# 30043    27792
# 30004    27282
# Name: Zip, dtype: int64

# %% [markdown]
# Some zips have a high number of registrants, meaning comparing an owner to owners with that matching zip will take a while. We may need to narrow it down more.

# %% [markdown]
# ### Eliminate any improper zip codes

# %% [markdown]
# View the kinds of improper zip codes and counts.

# %%
registry[(registry['Zip'].str.contains('^[a-z]') == True)] \
        .groupby('Zip')['Zip'] \
        .count() \
        .sort_values(ascending=False)
# Out:
# Zip
# ga       2
# and a    1
# billm    1
# f4v3b    1
# ga 30    1
# j0h 1    1
# j4y 0    1
# ky1-1    1
# l6p1y    1
# q        1
# regis    1
# sw153    1
# v        1
# w1t 4    1
# xv8ms    1
# Name: Zip, dtype: int64

# %% [markdown]
# NA values for Zip

# %%
len(registry[registry['Zip'].isna()].index)
# Out:
# 99135

# %% [markdown]
# ### Percent of Entries with Incorrect or Missing Zip

# %%
tot = len(registry[(registry['Zip'].str.contains('^[a-z]') == True) \
        | (registry['Zip'].isna())].index)

tot / len(registry.index) * 100
# Out:
# 3.076139820080987

# %% [markdown]
# ### Delete Entries with Bad Zips

# %%
registry = registry[(registry['Zip'].str.contains('^[a-z]') == False) | (registry['Zip'].notna())]

# %% [markdown]
# ### Delete Remaining Entries with Empty StreetAddress

# %%
init = len(registry.index)
registry = registry[registry['StreetAddress1'].notna()]
init - len(registry.index)
# Out:
# 4900

# %%
len(registry.index)
# Out:
# 3119193

# %% [markdown]
# ### Check if there multiple business registered under the same address

# %%
registry.groupby(['StreetAddress1'])['StreetAddress1'].count().sort_values(ascending=False).loc[lambda x : x > 1].head(10)
# Out:
# StreetAddress1
# 300 Colonial Center Parkway STE 100N    4840
# 300 Colonial Center Parkway             1207
# NO ADDR.                                1182
# 1209 N ORANGE ST                         638
# 1700 Northside Drive                     578
# 3900 Crown Rd SW #16709                  545
# 3350 Riverwood Parkway                   529
# 500 SUGAR MILL ROAD                      517
# 2859 Paces Ferry Road SE                 507
# 1465 Northside Drive NW                  462
# Name: StreetAddress1, dtype: int64

# %% [markdown]
# ### Percent of Businesses Registered Under an Address with > 1 Business

# %%
dup_addr = registry.groupby(['StreetAddress1'])['StreetAddress1'].count().sort_values(ascending=False).loc[lambda x : x > 1].sum()

# %%
dup_addr
# Out:
# 1352774

# %%
dup_addr / len(registry.index) * 100
# Out:
# 43.36935867706808

# %% [markdown]
# ### Finding: there are many businesses registered at the same address; will need to use name for matching as well.
# Additionally, some addresses in the business registry data have slight variations in capitalization, abbreviations, etc.

# %% [markdown]
# Drop NaN BusinessNames (3 total)

# %%
registry = registry.loc[registry['BusinessName'].notna()]

# %%
len(registry.index)
# Out:
# 3119190

# %% [markdown]
# ### Look at some individual cases to see how subsidaries are represented in the data

# %%
registry.loc[registry['BusinessName'].str.contains("Invitation Homes")]
# Out:
#          BusinessId                 BusinessName  \
# 1794844     1808195  Invitation Homes Realty LLC
# 2493978     2611760  Invitation Homes Realty Inc
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1794844  Foreign Limited Liability Company     Delaware            USA
# 2493978         Foreign Profit Corporation     Delaware            NaN
#
#               EntityStatus  Good Standing          NAICSCODE  \
# 1794844  Active/Compliance              1                NaN
# 2493978          Withdrawn              0  Any legal purpose
#
#                        StreetAddress1 StreetAddress2    City State    Zip  \
# 1794844  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 2493978   1717 Main Street Suite 2000            NaN  Dallas    TX  75201
#
#                Country Adrno
# 1794844  United States  1717
# 2493978  United States  1717

# %% [markdown]
# ### Do subsidaries share the same address as the parent corp? Invitation Homes and Progress Residential appear to, although Progress Residential has minor inconsistency in their StreetAddress.

# %%
registry.loc[registry['StreetAddress1'] == '1717 Main Street, Suite 2000']
# Out:
#          BusinessId                   BusinessName  \
# 1794844     1808195    Invitation Homes Realty LLC
# 1843180     1856558     IH3 PROPERTY GEORGIA, L.P.
# 1850123     1863507    2013-1 IH BORROWER G.P. LLC
# 1872678     1886086    2017-1 IH Borrower G.P. LLC
# 1872747     1886155        2017-1 IH Borrower L.P.
# 1948571     1962039    2014-2 IH BORROWER G.P. LLC
# 1965791     1979268    2014-3 IH BORROWER G.P. LLC
# 1990917     2004416       2015-1 IH2 BORROWER L.P.
# 1990929     2004428   2015-1 IH2 BORROWER G.P. LLC
# 2025607     2039132  2015-2 IH2  Borrower G.P. LLC
# 2054438     2067978              THR Lakewood L.P.
# 2054764     2068304   2015-3 IH2 BORROWER G.P. LLC
# 2069715     2084005   2015-4 IH3 BORROWER G.P. LLC
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1794844  Foreign Limited Liability Company     Delaware            USA
# 1843180        Foreign Limited Partnership     Delaware            USA
# 1850123  Foreign Limited Liability Company     Delaware            USA
# 1872678  Foreign Limited Liability Company     Delaware            USA
# 1872747        Foreign Limited Partnership     Delaware            USA
# 1948571  Foreign Limited Liability Company     Delaware            USA
# 1965791  Foreign Limited Liability Company     Delaware            USA
# 1990917        Foreign Limited Partnership     Delaware            USA
# 1990929  Foreign Limited Liability Company     Delaware            USA
# 2025607  Foreign Limited Liability Company     Delaware            USA
# 2054438        Foreign Limited Partnership     Delaware            USA
# 2054764  Foreign Limited Liability Company     Delaware            USA
# 2069715  Foreign Limited Liability Company     Delaware            NaN
#
#                  EntityStatus  Good Standing          NAICSCODE  \
# 1794844     Active/Compliance              1                NaN
# 1843180     Active/Compliance              1                NaN
# 1850123     Active/Compliance              1                NaN
# 1872678     Active/Compliance              1                NaN
# 1872747     Active/Compliance              1                NaN
# 1948571     Active/Compliance              1                NaN
# 1965791     Active/Compliance              1                NaN
# 1990917     Active/Compliance              1                NaN
# 1990929     Active/Compliance              1                NaN
# 2025607     Active/Compliance              1                NaN
# 2054438  Active/Noncompliance              1                NaN
# 2054764     Active/Compliance              1                NaN
# 2069715     Active/Compliance              1  Any legal purpose
#
#                        StreetAddress1 StreetAddress2    City State    Zip  \
# 1794844  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1843180  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1850123  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1872678  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1872747  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1948571  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1965791  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1990917  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 1990929  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 2025607  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 2054438  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 2054764  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
# 2069715  1717 Main Street, Suite 2000            NaN  Dallas    TX  75201
#
#                Country Adrno
# 1794844  United States  1717
# 1843180  United States  1717
# 1850123  United States  1717
# 1872678  United States  1717
# 1872747  United States  1717
# 1948571  United States  1717
# 1965791  United States  1717
# 1990917  United States  1717
# 1990929  United States  1717
# 2025607  United States  1717
# 2054438  United States  1717
# 2054764  United States  1717
# 2069715  United States  1717

# %%
registry.loc[registry['BusinessName'].str.contains("Progress Residential")]
# Out:
#          BusinessId                                   BusinessName  \
# 1969323     1982800           Progress Residential Borrower 5, LLC
# 2008026     2021539           Progress Residential Borrower 7, LLC
# 2045349     2058886           Progress Residential Borrower 9, LLC
# 2097296     2115452          Progress Residential Borrower 12, LLC
# 2310782     2361205           Progress Residential Borrower 1, LLC
# 2358349     2417707           Progress Residential Borrower 2, LLC
# 2390884     2456761           Progress Residential Borrower 3, LLC
# 2414830     2485457  Progress Residential Management Services, LLC
# 2464572     2546104            Progress Residential Borrower 4,LLC
# 2493097     2610722      Progress Residential Bridge Borrower, LLC
# 2543110     2672526           Progress Residential Borrower 6, LLC
# 2555351     2687258    Progress Residential Exchange Borrower, LLC
# 2577045     2712990           Progress Residential Borrower 8, LLC
# 2632988     2779393          Progress Residential Borrower 10, LLC
# 2649124     2798456          Progress Residential Borrower 11, LLC
# 2721267     2884886          Progress Residential Borrower 13, LLC
# 2762966     2933965          Progress Residential Borrower 14, LLC
# 2896315     3090053          Progress Residential Borrower 15, LLC
# 2980001     3189191                Progress Residential Homes, LLC
# 3069390     3293276          Progress Residential Borrower 16, LLC
# 3152877     3389447          Progress Residential Borrower 17, LLC
# 3174872     3414773         Progress Residential HVH Borrower, LLC
# 3216931     3463729          Progress Residential Borrower 18, LLC
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1969323  Foreign Limited Liability Company     Delaware            USA
# 2008026  Foreign Limited Liability Company     Delaware            USA
# 2045349  Foreign Limited Liability Company     Delaware            USA
# 2097296  Foreign Limited Liability Company     Delaware            NaN
# 2310782  Foreign Limited Liability Company     Delaware            NaN
# 2358349  Foreign Limited Liability Company     Delaware            NaN
# 2390884  Foreign Limited Liability Company     Delaware            NaN
# 2414830  Foreign Limited Liability Company     Delaware            NaN
# 2464572  Foreign Limited Liability Company     Delaware            NaN
# 2493097  Foreign Limited Liability Company     Delaware            NaN
# 2543110  Foreign Limited Liability Company     Delaware            NaN
# 2555351  Foreign Limited Liability Company     Delaware            NaN
# 2577045  Foreign Limited Liability Company     Delaware            NaN
# 2632988  Foreign Limited Liability Company     Delaware            NaN
# 2649124  Foreign Limited Liability Company     Delaware            NaN
# 2721267  Foreign Limited Liability Company     Delaware            NaN
# 2762966  Foreign Limited Liability Company     Delaware            NaN
# 2896315  Foreign Limited Liability Company     Delaware            NaN
# 2980001  Foreign Limited Liability Company     Delaware            NaN
# 3069390  Foreign Limited Liability Company     Delaware            NaN
# 3152877  Foreign Limited Liability Company     Delaware            NaN
# 3174872  Foreign Limited Liability Company     Delaware            NaN
# 3216931  Foreign Limited Liability Company     Delaware            NaN
#
#               EntityStatus  Good Standing          NAICSCODE  \
# 1969323  Active/Compliance              1                NaN
# 2008026  Active/Compliance              1                NaN
# 2045349  Active/Compliance              1                NaN
# 2097296  Active/Compliance              1  Any legal purpose
# 2310782  Active/Compliance              1  Any legal purpose
# 2358349  Active/Compliance              1  Any legal purpose
# 2390884  Active/Compliance              1  Any legal purpose
# 2414830  Active/Compliance              1  Any legal purpose
# 2464572  Active/Compliance              1  Any legal purpose
# 2493097  Active/Compliance              1  Any legal purpose
# 2543110  Active/Compliance              1  Any legal purpose
# 2555351  Active/Compliance              1  Any legal purpose
# 2577045  Active/Compliance              1  Any legal purpose
# 2632988  Active/Compliance              1  Any legal purpose
# 2649124  Active/Compliance              1  Any legal purpose
# 2721267  Active/Compliance              1  Any legal purpose
# 2762966  Active/Compliance              1  Any legal purpose
# 2896315  Active/Compliance              1  Any legal purpose
# 2980001  Active/Compliance              1  Any legal purpose
# 3069390  Active/Compliance              1  Any legal purpose
# 3152877  Active/Compliance              1  Any legal purpose
# 3174872  Active/Compliance              1  Any legal purpose
# 3216931  Active/Compliance              1  Any legal purpose
#
#                         StreetAddress1 StreetAddress2        City State  \
# 1969323             7500 N. Dobson Rd.      Suite 300  Scottsdale    AZ
# 2008026             7500 N. Dobson Rd.      Suite 300  Scottsdale    AZ
# 2045349            7500 N. Dobson Road      Suite 300  Scottsdale    AZ
# 2097296            7500 N. Dobson Road      Suite 300  Scottsdale    AZ
# 2310782              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2358349              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2390884              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2414830              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2464572              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2493097         7500 NORTH DOBSON ROAD      SUITE 300  SCOTTSDALE    AZ
# 2543110             7500 N. DOBSON RD.      SUITE 300  SCOTTSDALE    AZ
# 2555351            7500 N. DOBSON ROAD      SUITE 300  SCOTTSDALE    AZ
# 2577045              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 2632988  7500 N. DOBSON RD., SUITE 300            NaN  SCOTTSDALE    AZ
# 2649124             7500 N. DOBSON RD.      SUITE 300  SCOTTSDALE    AZ
# 2721267  7500 N. DOBSON RD., SUITE 300            NaN  SCOTTSDALE    AZ
# 2762966             7500 N. DOBSON RD.      SUITE 300  SCOTTSDALE    AZ
# 2896315  7500 N. Dobson Rd., Suite 300            NaN  Scottsdale    AZ
# 2980001              7500 N. Dobson Rd      Suite 300  Scottsdale    AZ
# 3069390  7500 N. Dobson Rd., Suite 300            NaN  Scottsdale    AZ
# 3152877   7500 N. Dobson Rd.,Suite 300            NaN  Scottsdale    AZ
# 3174872  7500 N. Dobson Rd., Suite 300            NaN  Scottsdale    AZ
# 3216931  7500 N. Dobson Rd., Suite 300            NaN  Scottsdale    AZ
#
#            Zip        Country Adrno
# 1969323  85256  United States  7500
# 2008026  85256  United States  7500
# 2045349  85256  United States  7500
# 2097296  85256  United States  7500
# 2310782  85256  United States  7500
# 2358349  85256  United States  7500
# 2390884  85256  United States  7500
# 2414830  85256  United States  7500
# 2464572  85256  United States  7500
# 2493097  85256  United States  7500
# 2543110  85256  United States  7500
# 2555351  85256  United States  7500
# 2577045  85256  United States  7500
# 2632988  85256  United States  7500
# 2649124  85256  United States  7500
# 2721267  85256  United States  7500
# 2762966  85256  United States  7500
# 2896315  85256  United States  7500
# 2980001  85256  United States  7500
# 3069390  85256  United States  7500
# 3152877  85256  United States  7500
# 3174872  85256  United States  7500
# 3216931  85256  United States  7500

# %%
registry.loc[registry['BusinessName'].str.contains("AMERICAN HOMES 4")]
# Out:
#          BusinessId                                    BusinessName  \
# 1682114     1694514                      AMERICAN HOMES 4 RENT, LLC
# 1683930     1696351           AMERICAN HOMES 4 RENT MANAGEMENT, LLC
# 1743391     1756447              RJ  AMERICAN HOMES 4 RENT ONE, LLC
# 1750069     1763202               RJ AMERICAN HOMES 4 RENT TWO, LLC
# 1783173     1796523  AMERICAN HOMES 4 RENT MANAGEMENT HOLDINGS, LLC
# 1807793     1821148      AMERICAN HOMES 4 RENT PROPERTIES FOUR, LLC
# 1807794     1821149       AMERICAN HOMES 4 RENT PROPERTIES TWO, LLC
# 1808134     1821489                AMERICAN HOMES 4 RENT, L.P. (DE)
# 1808561     1821916       AMERICAN HOMES 4 RENT PROPERTIES ONE, LLC
# 1850234     1863618     AMERICAN HOMES 4 RENT PROPERTIES EIGHT, LLC
# 1858509     1871902                  AMERICAN HOMES 4 RENT TRS, LLC
# 1999349     2012858                     AMERICAN HOMES 4 RENT, L.P.
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1682114  Foreign Limited Liability Company     Delaware            NaN
# 1683930  Foreign Limited Liability Company      Georgia            USA
# 1743391  Foreign Limited Liability Company     Delaware            NaN
# 1750069  Foreign Limited Liability Company     Delaware            NaN
# 1783173  Foreign Limited Liability Company      Georgia            USA
# 1807793  Foreign Limited Liability Company     Delaware            NaN
# 1807794  Foreign Limited Liability Company     Delaware            NaN
# 1808134        Foreign Limited Partnership     Delaware            USA
# 1808561  Foreign Limited Liability Company     Delaware            NaN
# 1850234  Foreign Limited Liability Company     Delaware            USA
# 1858509  Foreign Limited Liability Company     Delaware            USA
# 1999349        Foreign Limited Partnership     Delaware            USA
#
#               EntityStatus  Good Standing NAICSCODE  \
# 1682114          Withdrawn              0       NaN
# 1683930          Dissolved              0       NaN
# 1743391            Revoked              0       NaN
# 1750069  Active/Compliance              1       NaN
# 1783173  Active/Compliance              1       NaN
# 1807793          Withdrawn              0       NaN
# 1807794          Withdrawn              0       NaN
# 1808134          Withdrawn              0       NaN
# 1808561  Active/Compliance              1       NaN
# 1850234  Active/Compliance              1       NaN
# 1858509  Active/Compliance              1       NaN
# 1999349  Active/Compliance              1       NaN
#
#                                  StreetAddress1 StreetAddress2          City  \
# 1682114                  630 Trade Center Drive            NaN     Las Vegas
# 1683930    22917 Pacific Coast Highway, Ste 300            NaN        Malibu
# 1743391           30601 Agoura Road, Suite 200L            NaN  Agoura Hills
# 1750069          23975 Park Sorrento, Suite 300            NaN     Calabasas
# 1783173             23975 PARK SORRENTO STE 300            NaN     Calabasas
# 1807793                       30601 Agoura Road     Suite 200L  Agoura Hills
# 1807794                       30601 Agoura Road     Suite 200L  Agoura Hills
# 1808134  22917 PACIFIC COAST HIGHWAY, SUITE 300            NaN        Malibu
# 1808561             23975 PARK SORRENTO STE 300            NaN     Calabasas
# 1850234                     23975 Park Sorrento      Suite 300     Calabasas
# 1858509          23975 Park Sorrento, Suite 300            NaN     Calabasas
# 1999349          23975 Park Sorrento, Suite 300              `     Calabasas
#
#         State    Zip        Country  Adrno
# 1682114    NV  89119  United States    630
# 1683930    CA  90265            NaN  22917
# 1743391    CA  91301            NaN  30601
# 1750069    CA  91302  United States  23975
# 1783173    CA  91302  United States  23975
# 1807793    CA  91301  United States  30601
# 1807794    CA  91301  United States  30601
# 1808134    CA  90265            NaN  22917
# 1808561    CA  91302  United States  23975
# 1850234    CA  91302  United States  23975
# 1858509    CA  91302  United States  23975
# 1999349    CA  91302  United States  23975

# %%
registry.loc[registry['StreetAddress1'] == '30601 Agoura Road']
# Out:
#          BusinessId                                BusinessName  \
# 1690278     1702763                              AH4R-GA 2, LLC
# 1728857     1741756                              AH4R I GA, LLC
# 1807793     1821148  AMERICAN HOMES 4 RENT PROPERTIES FOUR, LLC
# 1807794     1821149   AMERICAN HOMES 4 RENT PROPERTIES TWO, LLC
# 1911951     1925391                AMH 2014-1 EQUITY OWNER, LLC
# 1940366     1953826                             SFR 2014-GA LLC
# 2000333     2013845                                AH4R-GA, LLC
# 2000344     2013856                              AH4R-GA 3, LLC
# 2000351     2013863                            AH4R - GA 4, LLC
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1690278  Foreign Limited Liability Company     Delaware            NaN
# 1728857  Foreign Limited Liability Company     Delaware            NaN
# 1807793  Foreign Limited Liability Company     Delaware            NaN
# 1807794  Foreign Limited Liability Company     Delaware            NaN
# 1911951  Foreign Limited Liability Company     Delaware            USA
# 1940366  Foreign Limited Liability Company     Delaware            USA
# 2000333  Foreign Limited Liability Company     Delaware            USA
# 2000344  Foreign Limited Liability Company     Delaware            USA
# 2000351  Foreign Limited Liability Company     Delaware            USA
#
#         EntityStatus  Good Standing NAICSCODE     StreetAddress1  \
# 1690278    Withdrawn              0       NaN  30601 Agoura Road
# 1728857    Withdrawn              0       NaN  30601 Agoura Road
# 1807793    Withdrawn              0       NaN  30601 Agoura Road
# 1807794    Withdrawn              0       NaN  30601 Agoura Road
# 1911951    Withdrawn              0       NaN  30601 Agoura Road
# 1940366    Withdrawn              0       NaN  30601 Agoura Road
# 2000333    Withdrawn              0       NaN  30601 Agoura Road
# 2000344    Withdrawn              0       NaN  30601 Agoura Road
# 2000351    Withdrawn              0       NaN  30601 Agoura Road
#
#         StreetAddress2          City State    Zip        Country  Adrno
# 1690278     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 1728857     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 1807793     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 1807794     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 1911951     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 1940366     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 2000333     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 2000344     Suite 200L  Agoura Hills    CA  91301  United States  30601
# 2000351     Suite 200L  Agoura Hills    CA  91301  United States  30601

# %%
registry.loc[registry['StreetAddress1'] == '630 Trade Center Drive']
# Out:
#          BusinessId                              BusinessName  \
# 1682114     1694514                AMERICAN HOMES 4 RENT, LLC
# 1909493     1922930  American Residential Properties TRS, LLC
# 2095702     2113663               ARP MANAGEMENT GEORGIA, LLC
# 2101887     2120694  American Residential Properties OP, L.P.
#
#                            BusinessTypeDesc ForeignState ForeignCountry  \
# 1682114   Foreign Limited Liability Company     Delaware            NaN
# 1909493   Foreign Limited Liability Company     Delaware            USA
# 2095702  Domestic Limited Liability Company      Georgia            NaN
# 2101887         Foreign Limited Partnership     Delaware            NaN
#
#         EntityStatus  Good Standing                           NAICSCODE  \
# 1682114    Withdrawn              0                                 NaN
# 1909493    Withdrawn              0                                 NaN
# 2095702   Terminated              0                   Any legal purpose
# 2101887    Withdrawn              0  Real Estate and Rental and Leasing
#
#                  StreetAddress1 StreetAddress2       City State    Zip  \
# 1682114  630 Trade Center Drive            NaN  Las Vegas    NV  89119
# 1909493  630 Trade Center Drive            NaN  Las Vegas    NV  89119
# 2095702  630 Trade Center Drive      SUITE 350  Las Vegas    NV  89119
# 2101887  630 Trade Center Drive            NaN  Las Vegas    NV  89119
#
#                Country Adrno
# 1682114  United States   630
# 1909493  United States   630
# 2095702  United States   630
# 2101887  United States   630

# %%
registry.loc[registry['StreetAddress1'] == '23975 Park Sorrento, Suite 300']
# Out:
#          BusinessId                                       BusinessName  \
# 1710107     1722791                          AH4R MANAGEMENT - GA, LLC
# 1750069     1763202                  RJ AMERICAN HOMES 4 RENT TWO, LLC
# 1858509     1871902                     AMERICAN HOMES 4 RENT TRS, LLC
# 1961334     1974808                            AMH 2014-2 BORROWER, LP
# 1976070     1989554                       AMH 2014-3 EQUITY OWNER, LLC
# 1999349     2012858                        AMERICAN HOMES 4 RENT, L.P.
# 2251144     2293400                               AMH Development, LLC
# 2414088     2484544           DALLAS WALK HOMEOWNERS ASSOCIATION, INC.
# 2542993     2672389         Hoke O'Kelly Mill Owners Association, Inc.
# 2650387     2799942                            AMH 2015-2 Borrower, LP
# 2671971     2825477                  RJ American Homes 4 Rent One, LLC
# 2691048     2848007      Overlook at Parkview Owners Association, Inc.
# 2816232     2996223                  AMH HB Westbrook Lake Venture LLC
# 2922929     3120998                    AMH HB Avery Creek Venture, LLC
# 3145170     3380596              AMH NB Development Vista Lake GA, LLC
# 3189576     3431745  AMH NB Development Retreat at Holly Springs GA...
# 3197584     3441042                 AMH Portfolio Management - GA, LLC
#
#                           BusinessTypeDesc ForeignState ForeignCountry  \
# 1710107  Foreign Limited Liability Company     Delaware            NaN
# 1750069  Foreign Limited Liability Company     Delaware            NaN
# 1858509  Foreign Limited Liability Company     Delaware            USA
# 1961334        Foreign Limited Partnership     Delaware            USA
# 1976070  Foreign Limited Liability Company     Delaware            USA
# 1999349        Foreign Limited Partnership     Delaware            USA
# 2251144  Foreign Limited Liability Company     Delaware            NaN
# 2414088     Domestic Nonprofit Corporation      Georgia            NaN
# 2542993     Domestic Nonprofit Corporation      Georgia            NaN
# 2650387        Foreign Limited Partnership     Delaware            NaN
# 2671971  Foreign Limited Liability Company     Delaware            NaN
# 2691048     Domestic Nonprofit Corporation      Georgia            NaN
# 2816232  Foreign Limited Liability Company     Delaware            NaN
# 2922929  Foreign Limited Liability Company     Delaware            NaN
# 3145170  Foreign Limited Liability Company     Delaware            NaN
# 3189576  Foreign Limited Liability Company     Delaware            NaN
# 3197584  Foreign Limited Liability Company     Delaware            NaN
#
#               EntityStatus  Good Standing          NAICSCODE  \
# 1710107  Active/Compliance              1                NaN
# 1750069  Active/Compliance              1                NaN
# 1858509  Active/Compliance              1                NaN
# 1961334  Active/Compliance              1                NaN
# 1976070  Active/Compliance              1                NaN
# 1999349  Active/Compliance              1                NaN
# 2251144  Active/Compliance              1  Any legal purpose
# 2414088  Active/Compliance              1  Any legal purpose
# 2542993  Active/Compliance              1  Any legal purpose
# 2650387  Active/Compliance              1  Any legal purpose
# 2671971  Active/Compliance              1  Any legal purpose
# 2691048  Active/Compliance              1  Any legal purpose
# 2816232  Active/Compliance              1  Any legal purpose
# 2922929  Active/Compliance              1  Any legal purpose
# 3145170  Active/Compliance              1  Any legal purpose
# 3189576  Active/Compliance              1  Any legal purpose
# 3197584  Active/Compliance              1  Any legal purpose
#
#                          StreetAddress1 StreetAddress2       City State  \
# 1710107  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 1750069  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 1858509  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 1961334  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 1976070  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 1999349  23975 Park Sorrento, Suite 300              `  Calabasas    CA
# 2251144  23975 Park Sorrento, Suite 300      Suite 300  Calabasas    CA
# 2414088  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2542993  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2650387  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2671971  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2691048  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2816232  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 2922929  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 3145170  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 3189576  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
# 3197584  23975 Park Sorrento, Suite 300            NaN  Calabasas    CA
#
#            Zip        Country  Adrno
# 1710107  91302  United States  23975
# 1750069  91302  United States  23975
# 1858509  91302  United States  23975
# 1961334  91302  United States  23975
# 1976070  91302  United States  23975
# 1999349  91302  United States  23975
# 2251144  91302  United States  23975
# 2414088  91302  United States  23975
# 2542993  91302  United States  23975
# 2650387  91302  United States  23975
# 2671971  91302  United States  23975
# 2691048  91302  United States  23975
# 2816232  91302  United States  23975
# 2922929  91302  United States  23975
# 3145170  91302  United States  23975
# 3189576  91302  United States  23975
# 3197584  91302  United States  23975

# %% [markdown]
# ### Finding: we need to heavily value address over name, but we cannot devalue name completely (since many businesses have the same address).

# %% [markdown]
# ### Let's look at some examples from the actual sales data - see if we can find these corporations

# %% [markdown]
# Note: full_sales is actually just 2022 sales in this example by mistake

# %%
full_sales = pd.read_csv('../output/final_sales_parcel_merged.csv')
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_14608\2767870617.py:1: DtypeWarning: Columns (0,1,2,3,4,8,28,31,43,45,48,51,53,74,75,77,80,84,91,93,95,141,144,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_sales = pd.read_csv('../output/final_sales_parcel_merged.csv')

# %%
len(full_sales.index)
# Out:
# 478699

# %%
full_sales = full_sales[full_sales['Own1'].notna()]
full_sales = full_sales[full_sales['Owner Adrstr'].notna()]

# %%
len(full_sales.index)
# Out:
# 426603

# %%
full_sales[full_sales['Own1'].str.contains("PROGRESS")][['Own1', 'Owner Adrno', 'Owner Adrstr']].sample(10)
# Out:
#                                             Own1  Owner Adrno  Owner Adrstr
# 430750      PROGRESS RESIDENTIAL BORROWER 13 LLC          NaN  P O BOX 4090
# 248153  PROGRESS RESIDENTIAL 2014 1 BORROWER LLC       6617.0    SCOTTSDALE
# 281979  PROGRESS RESIDENTIAL 2016 1 BORROWER LLC          NaN  P O BOX 4090
# 434069       PROGRESS RESIDENTIAL BORROWER 9 LLC          NaN  P O BOX 4090
# 48115      PROGRESSIVE DEVELOPMENT ALLIANCE, LLC        595.0      PIEDMONT
# 432708      PROGRESS RESIDENTIAL BORROWER 13 LLC          NaN  P O BOX 4090
# 462761                      PROGRESS ATLANTA LLC          NaN   PO BOX 4090
# 432133      PROGRESS RESIDENTIAL BORROWER 14 LLC          NaN  P O BOX 4090
# 376379       PROGRESS RESIDENTIAL BORROWER 4 LLC          NaN   PO BOX 4090
# 430007      PROGRESS RESIDENTIAL BORROWER 11 LLC          NaN  P O BOX 4090

# %%
full_sales[full_sales['Own1'].str.contains("AMERICAN HOMES")][['Own1', 'Owner Adrno', 'Owner Adrstr']].sample(10)
# Out:
#                                           Own1  Owner Adrno    Owner Adrstr
# 327807               SELECT AMERICAN HOMES LLC        950.0  EAGLES LANDING
# 257572  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 10164                 RALFS AMERICAN HOMES LLC        100.0     GLENDALOUGH
# 278122  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 276288  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 278057  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 276849  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 290698  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 290862  AMERICAN HOMES 4 RENT PROPERTIES EIGHT      30601.0          AGOURA
# 327812               SELECT AMERICAN HOMES LLC        950.0  EAGLES LANDING

# %%
full_sales[full_sales['Own1'].str.contains("INVITATION")][['Own1', 'Owner Adrno', 'Owner Adrstr']]
# Out:
# Empty DataFrame
# Columns: [Own1, Owner Adrno, Owner Adrstr]
# Index: []

# %%
full_sales[full_sales['Own1'].str.contains("INVITATION")][['Own1', 'Owner Adrno', 'Owner Adrstr']]
# Out:
# Empty DataFrame
# Columns: [Own1, Owner Adrno, Owner Adrstr]
# Index: []

# %%
full_sales[full_sales['Own1'].str.contains("Invitation")][['Own1', 'Owner Adrno', 'Owner Adrstr']]
# Out:
# Empty DataFrame
# Columns: [Own1, Owner Adrno, Owner Adrstr]
# Index: []

# %%
full_sales[full_sales['Own1'].str.contains("IH6")][['Own1', 'Owner Adrno', 'Owner Adrstr']]
# Out:
#                             Own1  Owner Adrno Owner Adrstr
# 303407  IH6 PROPERTY GEORGIA L P       8601.0     DUNWOODY
# 304200   IH6 PROPERTY GEORGIA LP       8601.0     DUNWOODY
# 305994   IH6 PROPERTY GEORGIA LP       8601.0     DUNWOODY
# 334587   IH6 PROPERTY GEORGIA LP       8601.0     DUNWOODY
# 478476   IH6 PROPERTY GEORGIA LP       1717.0         MAIN
# 478520   IH6 PROPERTY GEORGIA LP       1717.0         MAIN

# %%
registry.loc[registry['BusinessName'].str.contains("IH6")]
# Out:
#          BusinessId                BusinessName             BusinessTypeDesc  \
# 2085240     2101704  IH6 PROPERTY GEORGIA, L.P.  Foreign Limited Partnership
#
#         ForeignState ForeignCountry       EntityStatus  Good Standing  \
# 2085240     Delaware            NaN  Active/Compliance              1
#
#                  NAICSCODE    StreetAddress1 StreetAddress2    City State  \
# 2085240  Any legal purpose  1717 MAIN STREET     SUITE 2000  DALLAS    TX
#
#            Zip        Country Adrno
# 2085240  75201  United States  1717

# %%
full_sales.groupby(['GRANTEE'])['GRANTEE'].count().sort_values(ascending=False).head(50)
# Out:
# GRANTEE
# FEDERAL NATIONAL MORTGAGE ASSOCIATION       5226
# BANK OF AMERICA N A                         2468
# BAC HOME LOANS SERVICING LP                 2092
# WELLS FARGO BANK NA                         1909
# SECRETARY OF HOUSING & URBAN DEV            1783
# FEDERAL HOME LOAN MORTGAGE CORPORATION      1727
# FEDERAL NATIONAL MORTGAGE ASSN              1595
# WELLS FARGO BANK N A                        1576
# CITIMORTGAGE INC                            1467
# SUNTRUST MORTGAGE INC                       1399
# FEDERAL HOME LOAN MORTGAGE CORP             1271
# FEDERAL NATL MTG ASSN                       1180
# BANK OF NEW YORK MELLON THE                 1174
# SECRETARY OF HOUSING & URBAN DEVELOPMENT    1079
# CHASE HOME FINANCE LLC                       900
# REDUS ATLANTA SUBDIVISIONS LLC               849
# D R HORTON INC                               817
# STATE BANK & TRUST COMPANY                   780
# FEDERAL HOME LOAN MTG CORP                   749
# STB LOTS LLC                                 725
# CRM CENTRAL PROPERTIES LLC                   675
# GEOSAM CAPITAL US ATLANTA LP                 663
# BROCK BUILT HOMES LLC                        653
# DEED CO LLC                                  523
# BANK OF AMERICA NA                           510
# BRANCH BANKING & TRUST COMPANY               508
# CONTINENTAL ADVISORS LLC                     490
# HABITAT FOR HUMANITY IN ATLANTA INC          489
# NAJARIAN CAPITAL LLC                         465
# EAGLE GA I SPE LLC                           464
# JPMORGAN CHASE BANK NATIONAL ASSOCIATION     446
# REGIONS BANK                                 440
# DEUTSCHE BANK NATIONAL TRUST COMPANY TR      432
# U S BANK NATIONAL ASSOCIATION TR             407
# SHARP RESIDENTIAL LLC                        399
# JEFFERSON HOMES INC                          398
# GEORGIA ASSET RESOLUTION GROUP LLC           393
# PALMETTO FARMS GROUP LLC                     384
# BUILDERS PROFESSIONAL GROUP LLC              383
# FYR SFR BORROWER LLC                         383
# COMMUNITY & SOUTHERN BANK                    382
# FULTON COUNTY CITY OF ATLANTA LAND BANK      380
# NR DEED LLC                                  380
# SOUTHERN STATE INVESTMENTS LLC               374
# AURORA LOAN SERVICES LLC                     374
# SUNTRUST BANK                                365
# GMAC MORTGAGE LLC                            354
# REDUS ATLANTA HOUSING LLC                    347
# EVERBANK                                     342
# MF GEORGIA II LLC                            338
# Name: GRANTEE, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## ALGORITHM

# %% [markdown]
# Pre-processing:
# - Create separate owner zip and owner address number columns for faster comparison.
# - Lowercase all address and owner strings.
#
# Naive Approach:
# - Compare every entry of the sales data to every entry of the registry data; compare owner name and owner address separately and create a separate match score for each - this might result in a owner name that does not have the matched owner address...
# - Take the closest match and create new columns "matched_owner" with owner name, address, and match score, based on business registry data
# - Take only matches with high enough match score
#
# Issues:
# - There are 3M entries in the business registry data and 50K entries in sales data. That is 3M*50K = 150B comparisons using a slow metric (Levenshtein or other)
#
# Better Approach:
# - Group sales data into Owner Zipcodes. Group registry data into Owner Zipcodes.
# - Run the comparison between sales and registry data only when the zipcode matches. Only compare street name strings when adrno is the same. This is a much faster comparison (2 numbers than strings and no special similarity metric). It also reduces the search space; largest search space (zip code with most businesses) is 40K.
# - Given the best match for owner address, search through the business names registered to that address for the top 2 similar owner names.
# - Take the closest match (within zip code) and create new columns "matched_owner" with owner name, address, and match score, based on business registry data
# - Take only matches with high enough match score
# - Create a combined similarity metric at the end, using what we determine as best for coefficients for owner name similarity and owner address similarity.
#
# If still not fast enough- use an Approximate Nearest Neighbor search / find a way to accurately vectorize.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

# %%
matched_df = pd.DataFrame()

def find_closest(sale, registry_zip):
    match_score_adrr = 0
    match_address = None
    match_score_name = 0
    match_name = None

    for index, row in registry_zip.iterrows():
        if (sale['OWNER Adrno'] == sale['OWNER Adrno']) & (sale['OWNER Adrno'] == row['Adrno']):
            print("")
            print(sale['OWNER Adrstr'])
            print(row['StreetAddress1'])
            print("")
            ratio = fuzz.ratio(sale['OWNER Adrstr'].str.lower(), row['StreetAddress1'].str.lower())
            if ratio > match_score_adrr:
                match_score_adrr = ratio
                match_address = row['StreetAddress1']
    
    reduced = registry_zip[registry_zip['StreetAddress1'] == match_address]

    for index, row in reduced.iterrows():
        ratio = fuzz.ratio(sale['GRANTEE'].str.lower(), row['BusinessName'].str.lower())
        if ratio > match_score_name:
            match_score_name = ratio
            match_name = row['BusinessName']

    return match_address, match_score_adrr, match_name, match_score_name

def match_to_registry(sales, registry):
    matched = pd.DataFrame()
    first_flag = True

    for zip in sales['Zip1'].unique():
        sales_zip = sales[sales['Zip1'] == zip]
        registry_zip = registry[registry['Zip'] == zip]
        
        sales_zip[['match_address', 'match_score_adrr', 'match_name', 'match_score_name']] = \
            sales_zip.apply(lambda x: find_closest(x[['Zip1', 'OWNER Adrno', 'OWNER Adrstr', 'GRANTEE']], registry_zip), axis=1).tolist()
    
        if first_flag:
            first_flag = False
            matched = sales_zip
        else:
            matched = pd.concat([matched, sales_zip])

    return matched

# %%
def match_fuzz(df_1, df_2, key1, key2, limit=2):
    search = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, search, limit=limit))
    df_1['matches'] = m
    
    return df_1

# %%
sales_sub = full_sales[full_sales['Zip1'] == '30313']
registry_sub = registry[registry['Zip'] == '30313']

matched = match_fuzz(sales_sub, registry_sub, 'Own1', 'BusinessName')
matched['matches']
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_14608\3461157588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['matches'] = m
# 49251     [(LUTHER H. RANDALL III-OXFORD, LLC, 86), (TA ...
# 49252     [(LUTHER H. RANDALL III-OXFORD, LLC, 86), (TA ...
# 50860     [(REAL ESTATE SORS LLC, 86), (THURN & LINDBERG...
# 119129    [(Pristine Refinement by Christopher McKinley,...
# 119131    [(Pristine Refinement by Christopher McKinley,...
#                                 ...
# 446450    [(LOFTMAN CONSULTING, INC., 52), (PAUL RIECHMA...
# 446451    [(LOFTMAN CONSULTING, INC., 52), (PAUL RIECHMA...
# 446452    [(LOFTMAN CONSULTING, INC., 52), (PAUL RIECHMA...
# 446453    [(LOFTMAN CONSULTING, INC., 52), (PAUL RIECHMA...
# 446455    [(Ohm Salon and Spa LLC, 56), (OMEGA SALES, IN...
# Name: matches, Length: 693, dtype: object

# %%
matched[['Own1', 'matches']].sample(10)
# Out:
#                                       Own1  \
# 344357      JACKSON LEO J II & GWENDOLYN J
# 196324                  KNIGHT FREDERICK C
# 196071                      MARTIN JASON D
# 344337            OLIVIA J BYNUM TRUST THE
# 198521  RUSSELL REALTY LIMITED PARTNERSHIP
# 195291                        TAGO FUMIAKI
# 195359                       FARINHA GYASI
# 344688              SERYUS DEVELOPMENT LLC
# 196335                     MC KINNON BONNY
# 344657                  CHAPPELL MELBREY E
#
#                                                   matches
# 344357  [(J. LUCKEY, INC., 86), (BNV/RNU NORTHSIDE PHA...
# 196324  [(WINGNUTS RESTAURANTS, L.L.C., 86), (JOHNNY C...
# 196071  [(D.J. CONSTRUCTION/CAR DETAIL INC., 86), (K D...
# 344337  [(J. LUCKEY, INC., 86), (THE S.T.L. (SKIES THE...
# 198521  [(URBANSCAPE REALTY, INC., 86), (RUSSELL NEW Y...
# 195291  [(2ENGAGE FINANCIAL MEDIA, LLC, 52), (Maverick...
# 195359  [(SFOGARSI, INC., 53), (Antioch United Methodi...
# 344688  [(SERYUS DEVELOPMENT LLC, 100), (LUTHER H. RAN...
# 196335  [(INFERNO MUSIC, INC., 53), (REEVES MACHINE CO...
# 344657  [(QUALITY R.E.A.L. SOLUTIONS, LLC, 86), (E. J....

# %%
full_sales[:100][['GRANTOR','GRANTEE','SALES PRICE', 'Own1', 'Owner Adrno', 'Owner Adrstr', 'Zip1', 'Owner Cityname']].head(2)
